# %% [markdown]
# # 常用指令

# %% [markdown]
# `%cd 文件夹路径`

# %%
# 转到 桌面 这个路径
# %cd D:/Desktop
# Out:
# D:\Desktop

# %% [markdown]
# ## 在Jupyter Notebook中安装库

# %% [markdown]
#  '!'执行系统命令

# %%
# !pip install panada

# %%
# !pip install --upgrade numpy

# %% [markdown]
# # 快捷键

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - `alt` + `enter` ：执行本单元格命令并创建新的单元格

# %% [markdown]
# # 互动模式

# %%
from ipywidgets import interact

# %%
def f(x):
    print(x)

# %%
interact(f, x=3)
# Out:
# interactive(children=(IntSlider(value=3, description='x', max=9, min=-3), Output()), _dom_classes=('widget-int…
# <function __main__.f(x)>

# %%
interact(f,x=(1,10))
# Out:
# interactive(children=(IntSlider(value=5, description='x', max=10, min=1), Output()), _dom_classes=('widget-int…
# <function __main__.f(x)>

# %%
interact(f,x = '你好')
# Out:
# interactive(children=(Text(value='你好', description='x'), Output()), _dom_classes=('widget-interact',))
# <function __main__.f(x)>

# %%
interact(f, x=['武汉',"广州"])
# Out:
# interactive(children=(Dropdown(description='x', options=('武汉', '广州'), value='武汉'), Output()), _dom_classes=('w…
# <function __main__.f(x)>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-5,5,1000)

def draw(n=1):
    y =np.sinc(n*x)
    plt.plot(x,y, lw =3)
    plt.show()

# %%
interact(draw, n=(1,15))
# Out:
# interactive(children=(IntSlider(value=1, description='n', max=15, min=1), Output()), _dom_classes=('widget-int…
# <function __main__.draw(n=1)>

# %% [markdown]
# # 参考资源

# %% [markdown]
# # 配置
#
# - [把Jupyter Notebook配置成Coding神器](http://resuly.me/2017/11/03/jupyter-config-for-windows/)
# - [Windows下有什么办法提高conda install的速度？](https://www.zhihu.com/question/38252144)
# - [**windows下通过ssh远程访问Jupyter notebook进行交互式编程**](http://www.zsxrpd.com/blog/?p=921)
#
# - 服务器使用Jupyter Notebook
#
#     ```bash
#     wget https://repo.anaconda.com/archive/Anaconda3-2019.10-Linux-x86_64.sh
#     sudo bash Anaconda3-2019.10-Linux-x86_64.sh
#     ## 开始进入安装，按提示一步步执行即可
#
#     #使得安装生效
#     source ~/.bashrc
#
#     #创建配置文件
#     jupyter notebook --generate-config
#
#     # Verifying your installation
#     conda list
#
#     # 设置访问密码
#     jupyter notebook password
#     ```
#
#     - 生成hash密码（免得以后每次登陆都要输入密码）
#
#     ```bash
#     from notebook.auth import passwd
#     passwd()
#     # Enter password:
#     # Verify password:
#     # Out[2]: 'sha1:67c9e60bb8b6:9ffede0825894254b2e042ea597d771089e11aed'
#     ```
#
#     - 将hash密码添加到配置文件中
#
#     ```bash
#     vim /root/.jupyter/jupyter_notebook_config.py
#     ```
#
#     ```bash
#     # 270行改为
#     c.NotebookApp.password = u'sha1:67c9e60bb8b6:9ffede0825894254b2e042ea597d771089e11aed'
#
#     # 80行改为
#     c.NotebookApp.allow_remote_access = True
#     ```
#
#     。。。。更多请参考：
#
#     [如何设置远程访问的Jupyter Notebook服务器-04（服务器篇）](https://zhuanlan.zhihu.com/p/64524822)
#
#
# - references
#
#     [Installing on Linux - Anaconda documentation](https://docs.anaconda.com/anaconda/install/linux/)
#
#     - Vultr - [How to Install Jupyter Notebook on a Vultr CentOS 7 Server Instance](https://www.vultr.com/docs/how-to-install-jupyter-notebook-on-a-vultr-centos-7-server-instance)?
#     -
# - fix bugs
#     - [pip 或者 conda 安装出现permission denied情况的解决方法](https://blog.csdn.net/weixin_41483813/article/details/82670587)
#
#     ```
#     sudo chown -R 501:20  C:/Anaconda3/
#     ```
#
#     也有人推荐用管理员身份运行Anaconda
#
#     - [launching jupyter i get kernel error](https://github.com/jupyter/notebook/issues/2301)
#
#         解决办法：cmd输入
#
#
#     ```
#     python -m ipykernel install --user
#     ```
#
#     - 环境变量
#
#     ```
#     F:\Anaconda3
#     F:\Anaconda3\Scripts
#     F:\Anaconda3\Library\bin
#     ```

# %% [markdown]
# ## py转ipynb
#
# ```bash
# ipynb-py-convert  "D:\work\#py\ds\大数据数学基础（Python语言描述）\第6章 多元统计分析\习题程序\code\第6题 课后习题.py"		               	"D:\work\#py\ds\大数据数学基础（Python语言描述）\第6章 多元统计分析\习题程序\code\第6题 课后习题.ipynb"
#
# ```
#
# ## 安装与卸载插件
#
# ```bash
# jupyter labextension install  @krassowski/jupyterlab-lsp
#
# jupyter labextension uninstall  @krassowski/jupyterlab-lsp
# ```

# %% [markdown]
# # Extension
#
# - https://github.com/mauhai/awesome-jupyterlab
# ![image.png](attachment:image.png)
