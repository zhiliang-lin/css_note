# %% [markdown]
# # 准备知识

# %% [markdown]
# ## 网络爬虫（web crawler）

# %% [markdown]
# 1. **```定义```**：<br>
#     - 在互联网中自动采集与整理数据信息<br>
#     <br>
# 2. **```可行性```**：<br>
#     - <u>有权限</u>，如果没有权限，便不能爬取，例如银行的后台数据
#     - <u>能看到</u>，一些小众论坛只有在登录情况下才能查看，那么需要模拟登录，让电脑“看得到”数据
# 3. **```伦理```**：<br>
#     - 除了一般的研究伦理，如果爬取的是<u>特定地区的论坛</u>，研究报告时可能需要匿名化处理。

# %% [markdown]
# ## 基本思路

# %% [markdown]
# |**步骤**|任务|说明|方法|
# |:----:|:----:|:-----|:----:|
# |**1**|**生成网址**|分析**<mark>网址规律</mark>**，批量生成网址|for循环，format函数|
# |2|请求+获取网页数据|模拟人工打开网页，并将网页存储为数据对象|requests包|
# |**3**|**解析数据**|分析数据规律，整理出所需字段|**<mark>pyquery包</mark>**，json包<br>（还有**<mark>lxml包和beautifulsoup4包</mark>**）|
# |4|存储数据|使用csv包将数据存储到csv文件中|csv包|
# |5|批量爬取|对所有网址循环步骤2-4|for循环|

# %% [markdown]
# # 生成网址

# %% [markdown]
# ## 分析网址规律

# %% [markdown]
# 1. **```任务对象```**：
#     - https://book.douban.com/tag/哲学<br>
# <br>
# <br>
# 2. **```基本情况```**：
#     - 每翻一页，网址中的某个**<u>```数字发生规律性变化```</u>**
#     - 每页20本书的信息，最多翻到50页

# %% [markdown]
# 3. **```规律```**：
# - **<u>```原网址```</u>**：
#     * https://book.douban.com/tag/哲学?start=0&type=T
#     * https://book.douban.com/tag/哲学?start=20&type=T
#     * https://book.douban.com/tag/哲学?start=40&type=T
#     * https://book.douban.com/tag/哲学?start=60&type=T
#     * ……
#     * https://book.douban.com/tag/哲学?start=960&type=T
#     * https://book.douban.com/tag/哲学?start=980&type=T<br>
# <br>
# - **<u>```总结规律```</u>**：
#     * 第1页，数字为0
#     * 第2页，数字为20
#     * 第3页，数字为40
#     * 第4页，数字为60
#     * ……
#     * 第49页，数字为960
#     * 第50页，数字为980
# <br>
# <br>
#     * <mark><big>第p页，数字为(p-1)*20</big></mark>

# %% [markdown]
# ## 批量生成网址

# %%
# 尝试用format替换数字
'https://book.douban.com/tag/哲学?start={num}&type=T'.format(num=100)
# 'https://book.douban.com/tag/哲学?start={num}&type=T'.format(num=0)   # num取0
# Out:
# 'https://book.douban.com/tag/哲学?start=100&type=T'

# %%
'https://book.douban.com/tag/哲学?start={num}&type=T'.format(num=20)  # num取20

# %%
# 简写
template = 'https://book.douban.com/tag/哲学?start={num}&type=T'
template.format(num=20)

# %%
# 循环生成网址，并存入网址列表中
url_list = []    # 生成空列表，用于存储网址
template = 'https://book.douban.com/tag/哲学?start={num}&type=T'
for p in range(1,11):   # range取1到50，因豆瓣限制50页
    url = template.format(num=(p-1)*20)    # 取1时，为(1-1)*20，即num为0，以此类推
    url_list.append(url)   # 将上面获得的url【添加进】列表

# %%
# 查看url_list情况（获得50页的网址）
url_list
# Out:
# ['https://book.douban.com/tag/哲学?start=0&type=T',
#  'https://book.douban.com/tag/哲学?start=20&type=T',
#  'https://book.douban.com/tag/哲学?start=40&type=T',
#  'https://book.douban.com/tag/哲学?start=60&type=T',
#  'https://book.douban.com/tag/哲学?start=80&type=T',
#  'https://book.douban.com/tag/哲学?start=100&type=T',
#  'https://book.douban.com/tag/哲学?start=120&type=T',
#  'https://book.douban.com/tag/哲学?start=140&type=T',
#  'https://book.douban.com/tag/哲学?start=160&type=T',
#  'https://book.douban.com/tag/哲学?start=180&type=T']

# %%
# 函数：生成网址  generate_url_list()
# 返回值：url_list为网址列表
def generate_url_list():   # 添加：定义函数名
    url_list = []
    template = 'https://book.douban.com/tag/哲学?start={num}&type=T'
    for p in range(1,6):
        url = template.format(num=(p-1)*20)
        url_list.append(url)
    return url_list        # 添加：返回网址列表

# %%
# 调用函数  generate_url_list()
url_list_tmp = generate_url_list()
url_list_tmp
# Out:
# ['https://book.douban.com/tag/哲学?start=0&type=T',
#  'https://book.douban.com/tag/哲学?start=20&type=T',
#  'https://book.douban.com/tag/哲学?start=40&type=T',
#  'https://book.douban.com/tag/哲学?start=60&type=T',
#  'https://book.douban.com/tag/哲学?start=80&type=T']

# %% [markdown]
# # 请求+获取网页数据

# %% [markdown]
# - 以第1页为例，来请求并获取网页数据
# - 例子：https://book.douban.com/tag/哲学?start=0&type=T

# %%
import requests   # 导入requests包

url = 'https://book.douban.com/tag/哲学?start=0&type=T'
resp = requests.get(url)   # 用get向服务器请求获取数据
resp # 查看状态码，返回码418说明访问不成功，需要伪装访问，假装是人工打开网页
# Out:
# <Response [418]>

# %% [markdown]
# ## 1. **```状态码```**：

# %% [markdown]
#     * 1开头：信息状态码
#     * 2开头：成功状态码
#     * 3开头：重定向状态码
#     * 4开头：客户端错误状态码
#     * 5开头：服务端错误状态码

# %%
resp.text
# Out:
# ''

# %% [markdown]
# ## 2. **```应对方式```**：

# %% [markdown]
# 加入请求头headers，一般包括user-agent、cookie和referer等

# %% [markdown]
#     * **<u>```user-agent```</u>**：浏览器类型及版本、操作系统及版本、浏览器内核等的信息标识
#     * **<u>```cookie```</u>**：用于识别用户身份、记录历史的一段数据（浏览器访问服务器后，服务器传给浏览器的）
#     * **<u>```referer```</u>**：告诉服务器该网页是从哪个页面链接过来的

# %%
# 尝试加入user-agent
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)   \
                           AppleWebKit/537.36 (KHTML, like Gecko)  \
                           Chrome/92.0.4515.131 Safari/537.36'}
resp = requests.get(url, headers=headers)  # 设置参数headers
resp #返回码200说明访问成功
# Out:
# <Response [200]>

# %%
# 查看返回内容，搜索该页面的“人类简史”是否在返回的文本中，确认与网页一致
resp.text
# Out:
# '\n\n<!DOCTYPE html>\n<html lang="zh-cmn-Hans" class="ua-windows ua-webkit book-new-nav">\n<head>\n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n  <title>\n  豆瓣图书标签: 哲学\n</title>\n  \n<script>!function(e){var o=function(o,n,t){var c,i,r=new Date;n=n||30,t=t||"/",r.setTime(r.getTime()+24*n*60*60*1e3),c="; expires="+r.toGMTString();for(i in o)e.cookie=i+"="+o[i]+c+"; path="+t},n=function(o){var n,t,c,i=o+"=",r=e.cookie.split(";");for(t=0,c=r.length;t<c;t++)if(n=r[t].replace(/^\\s+|\\s+$/g,""),0==n.indexOf(i))return n.substring(i.length,n.length).replace(/\\"/g,"");return null},t=e.write,c={"douban.com":1,"douban.fm":1,"google.com":1,"google.cn":1,"googleapis.com":1,"gmaptiles.co.kr":1,"gstatic.com":1,"gstatic.cn":1,"google-analytics.com":1,"googleadservices.com":1},i=function(e,o){var n=new Image;n.onload=function(){},n.src="https://www.douban.com/j/except_report?kind=ra022&reason="+encodeURIComponent(e)+"&environment="+encodeURIComponent(o)},r=function(o){try{t.call(e,o)}catch(e){t(o)}},a=/<script.*?src\\=["\']?([^"\'\\s>]+)/gi,g=/http:\\/\\/(.+?)\\.([^\\/]+).+/i;e.writeln=e.write=function(e){var t,l=a.exec(e);return l&&(t=g.exec(l[1]))?c[t[2]]?void r(e):void("tqs"!==n("hj")&&(i(l[1],location.href),o({hj:"tqs"},1),setTimeout(function(){location.replace(location.href)},50))):void r(e)}}(document);</script>\n\n  \n  <meta http-equiv="Pragma" content="no-cache">\n  <meta http-equiv="Expires" content="Sun, 6 Mar 2005 01:00:00 GMT">\n  \n  <script>var _head_start = new Date();</script>\n  \n  <link href="https://img1.doubanio.com/f/vendors/02814fbb5bee25484516bd0a642af695f7ec5a83/css/douban.css" rel="stylesheet" type="text/css">\n  <link href="https://img2.doubanio.com/cuphead/book-static/common/master.dd2c2.css" rel="stylesheet" type="text/css">\n\n  <link href="https://img2.doubanio.com/cuphead/book-static/base/init.e399f.css" rel="stylesheet">\n  <style type="text/css"></style>\n  <script src="https://img1.doubanio.com/f/vendors/0511abe9863c2ea7084efa7e24d1d86c5b3974f1/js/jquery-1.10.2.min.js"></script>\n  <script src="https://img1.doubanio.com/f/vendors/aa9559674f2476cdc16f755b3cdc4ebc478db669/js/douban.js"></script>\n  <script src="https://img1.doubanio.com/cuphead/book-static/common/master.307d7.js"></script>\n  \n\n  \n  <script>  </script>\n  <style type="text/css">\n    .ebook-link a:link,\n    .ebook-link a:visited {\n      color: #973f31;\n    }\n    .ebook-link a:hover {\n      color: #fff;\n      background: #973f31;\n    }\n  </style>\n\n  <link rel="shortcut icon" href="https://img1.doubanio.com/favicon.ico" type="image/x-icon">\n</head>\n<body>\n  \n    <script>var _body_start = new Date();</script>\n    \n  \n\n\n\n    <link href="//img3.doubanio.com/dae/accounts/resources/164cfd8/shire/bundle.css" rel="stylesheet" type="text/css">\n\n\n\n<div id="db-global-nav" class="global-nav">\n  <div class="bd">\n    \n<div class="top-nav-info">\n  <a href="https://accounts.douban.com/passport/login?source=book" class="nav-login" rel="nofollow">登录/注册</a>\n</div>\n\n\n    <div class="top-nav-doubanapp">\n  <a href="https://www.douban.com/doubanapp/app?channel=top-nav" class="lnk-doubanapp">下载豆瓣客户端</a>\n  <div id="doubanapp-tip">\n    <a href="https://www.douban.com/doubanapp/app?channel=qipao" class="tip-link">豆瓣 <span class="version">6.0</span> 全新发布</a>\n    <a href="javascript: void 0;" class="tip-close">×</a>\n  </div>\n  <div id="top-nav-appintro" class="more-items">\n    <p class="appintro-title">豆瓣</p>\n    <p class="qrcode">扫码直接下载</p>\n    <div class="download">\n      <a href="https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=iOS">iPhone</a>\n      <span>·</span>\n      <a href="https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=Android" class="download-android">Android</a>\n    </div>\n  </div>\n</div>\n\n    \n\n\n<div class="global-nav-items">\n  <ul>\n    <li class="">\n      <a href="https://www.douban.com" target="_blank" data-moreur ...

# %%
# 将返回内容放入html中，html为str
html = resp.text
html
type(html)
# Out:
# str

# %%
# 函数：获得html  get_html(url)
# 参数说明：url为单个网址
# 返回值：html为网址的html数据，即网页源代码的字符串
def get_html(url):         # 添加：定义函数名
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)   \
                               AppleWebKit/537.36 (KHTML, like Gecko)  \
                               Chrome/92.0.4515.131 Safari/537.36'}
    resp = requests.get(url,headers=headers)
    html = resp.text
    return html            # 添加：返回网址的html数据

# %%
# 调用函数get_html(url)
url_tmp = 'https://book.douban.com/tag/哲学?start=900&type=T'  # 第46页
html_tmp = get_html(url_tmp)
html_tmp
# Out:
# '\n\n<!DOCTYPE html>\n<html lang="zh-cmn-Hans" class="ua-windows ua-webkit book-new-nav">\n<head>\n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n  <title>\n  豆瓣图书标签: 哲学\n</title>\n  \n<script>!function(e){var o=function(o,n,t){var c,i,r=new Date;n=n||30,t=t||"/",r.setTime(r.getTime()+24*n*60*60*1e3),c="; expires="+r.toGMTString();for(i in o)e.cookie=i+"="+o[i]+c+"; path="+t},n=function(o){var n,t,c,i=o+"=",r=e.cookie.split(";");for(t=0,c=r.length;t<c;t++)if(n=r[t].replace(/^\\s+|\\s+$/g,""),0==n.indexOf(i))return n.substring(i.length,n.length).replace(/\\"/g,"");return null},t=e.write,c={"douban.com":1,"douban.fm":1,"google.com":1,"google.cn":1,"googleapis.com":1,"gmaptiles.co.kr":1,"gstatic.com":1,"gstatic.cn":1,"google-analytics.com":1,"googleadservices.com":1},i=function(e,o){var n=new Image;n.onload=function(){},n.src="https://www.douban.com/j/except_report?kind=ra022&reason="+encodeURIComponent(e)+"&environment="+encodeURIComponent(o)},r=function(o){try{t.call(e,o)}catch(e){t(o)}},a=/<script.*?src\\=["\']?([^"\'\\s>]+)/gi,g=/http:\\/\\/(.+?)\\.([^\\/]+).+/i;e.writeln=e.write=function(e){var t,l=a.exec(e);return l&&(t=g.exec(l[1]))?c[t[2]]?void r(e):void("tqs"!==n("hj")&&(i(l[1],location.href),o({hj:"tqs"},1),setTimeout(function(){location.replace(location.href)},50))):void r(e)}}(document);</script>\n\n  \n  <meta http-equiv="Pragma" content="no-cache">\n  <meta http-equiv="Expires" content="Sun, 6 Mar 2005 01:00:00 GMT">\n  \n  <script>var _head_start = new Date();</script>\n  \n  <link href="https://img1.doubanio.com/f/vendors/02814fbb5bee25484516bd0a642af695f7ec5a83/css/douban.css" rel="stylesheet" type="text/css">\n  <link href="https://img2.doubanio.com/cuphead/book-static/common/master.dd2c2.css" rel="stylesheet" type="text/css">\n\n  <link href="https://img2.doubanio.com/cuphead/book-static/base/init.e399f.css" rel="stylesheet">\n  <style type="text/css"></style>\n  <script src="https://img1.doubanio.com/f/vendors/0511abe9863c2ea7084efa7e24d1d86c5b3974f1/js/jquery-1.10.2.min.js"></script>\n  <script src="https://img1.doubanio.com/f/vendors/aa9559674f2476cdc16f755b3cdc4ebc478db669/js/douban.js"></script>\n  <script src="https://img1.doubanio.com/cuphead/book-static/common/master.307d7.js"></script>\n  \n\n  \n  <script>  </script>\n  <style type="text/css">\n    .ebook-link a:link,\n    .ebook-link a:visited {\n      color: #973f31;\n    }\n    .ebook-link a:hover {\n      color: #fff;\n      background: #973f31;\n    }\n  </style>\n\n  <link rel="shortcut icon" href="https://img1.doubanio.com/favicon.ico" type="image/x-icon">\n</head>\n<body>\n  \n    <script>var _body_start = new Date();</script>\n    \n  \n\n\n\n    <link href="//img3.doubanio.com/dae/accounts/resources/164cfd8/shire/bundle.css" rel="stylesheet" type="text/css">\n\n\n\n<div id="db-global-nav" class="global-nav">\n  <div class="bd">\n    \n<div class="top-nav-info">\n  <a href="https://accounts.douban.com/passport/login?source=book" class="nav-login" rel="nofollow">登录/注册</a>\n</div>\n\n\n    <div class="top-nav-doubanapp">\n  <a href="https://www.douban.com/doubanapp/app?channel=top-nav" class="lnk-doubanapp">下载豆瓣客户端</a>\n  <div id="doubanapp-tip">\n    <a href="https://www.douban.com/doubanapp/app?channel=qipao" class="tip-link">豆瓣 <span class="version">6.0</span> 全新发布</a>\n    <a href="javascript: void 0;" class="tip-close">×</a>\n  </div>\n  <div id="top-nav-appintro" class="more-items">\n    <p class="appintro-title">豆瓣</p>\n    <p class="qrcode">扫码直接下载</p>\n    <div class="download">\n      <a href="https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=iOS">iPhone</a>\n      <span>·</span>\n      <a href="https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=Android" class="download-android">Android</a>\n    </div>\n  </div>\n</div>\n\n    \n\n\n<div class="global-nav-items">\n  <ul>\n    <li class="">\n      <a href="https://www.douban.com" target="_blank" data-moreur ...

# %% [markdown]
# # 解析数据

# %% [markdown]
# - 上面获得的html数据是杂乱的，需要把它**整理成结构化的数据**，即解析数据
# - 方式：用开发者工具中的elements，分析字段的分布情况，找出具有**定位唯一性的标签**

# %%
from pyquery import PyQuery  #导入pyquery包

doc = PyQuery(html) # 将html字符串转换为pyquery数据，便于解析
type(doc)   # 数据类型为pyquery.pyquery.PyQuery
doc.text()    # 数据变“干净”了
# Out:
# '豆瓣图书标签: 哲学\n!function(e){var o=function(o,n,t){var c,i,r=new Date;n=n||30,t=t||"/",r.setTime(r.getTime()+24*n*60*60*1e3),c="; expires="+r.toGMTString();for(i in o)e.cookie=i+"="+o[i]+c+"; path="+t},n=function(o){var n,t,c,i=o+"=",r=e.cookie.split(";");for(t=0,c=r.length;t<c;t++)if(n=r[t].replace(/^\\s+|\\s+$/g,""),0==n.indexOf(i))return n.substring(i.length,n.length).replace(/\\"/g,"");return null},t=e.write,c={"douban.com":1,"douban.fm":1,"google.com":1,"google.cn":1,"googleapis.com":1,"gmaptiles.co.kr":1,"gstatic.com":1,"gstatic.cn":1,"google-analytics.com":1,"googleadservices.com":1},i=function(e,o){var n=new Image;n.onload=function(){},n.src="https://www.douban.com/j/except_report?kind=ra022&reason="+encodeURIComponent(e)+"&environment="+encodeURIComponent(o)},r=function(o){try{t.call(e,o)}catch(e){t(o)}},a=/<script.*?src\\=["\']?([^"\'\\s>]+)/gi,g=/http:\\/\\/(.+?)\\.([^\\/]+).+/i;e.writeln=e.write=function(e){var t,l=a.exec(e);return l&&(t=g.exec(l[1]))?c[t[2]]?void r(e):void("tqs"!==n("hj")&&(i(l[1],location.href),o({hj:"tqs"},1),setTimeout(function(){location.replace(location.href)},50))):void r(e)}}(document);\nvar _head_start = new Date();\n.ebook-link a:link, .ebook-link a:visited { color: #973f31; } .ebook-link a:hover { color: #fff; background: #973f31; }\nvar _body_start = new Date();\n登录/注册\n下载豆瓣客户端\n豆瓣 6.0 全新发布 ×\n豆瓣\n扫码直接下载\niPhone · Android\n豆瓣\n读书\n电影\n音乐\n同城\n小组\n阅读\nFM\n时间\n豆品\n;window._GLOBAL_NAV = { DOUBAN_URL: "https://www.douban.com", N_NEW_NOTIS: 0, N_NEW_DOUMAIL: 0 };\n豆瓣读书\n搜索：\n购书单\n电子图书\n豆瓣书店\n2022年度榜单\n2022书影音报告\n购物车\n<li data-link="{{= url}}"> <a href="{{= url}}" onclick="moreurl(this, {from:\'book_search_sugg\', query:\'{{= keyword }}\', subject_id:\'{{= id}}\', i: \'{{= index}}\', type: \'{{= type}}\'})"> <img src="{{= pic}}" width="40" /> <div> <em>{{= title}}</em> {{if year}} <span>{{= year}}</span> {{/if}} <p> {{if type == "b"}} {{= author_name}} {{else type == "a" }} {{if en_name}} {{= en_name}} {{/if}} {{/if}} </p> </div> </a> </li>\n豆瓣图书标签: 哲学\n综合排序 \xa0/\xa0 按出版日期排序 \xa0/\xa0 按评价排序\n苏格拉底 : 我们的同时代人\n[英] 保罗·约翰逊 / 郝苑 / 广西师范大学出版社 / 2023-9 / 58\n9.0 (71人评价)\n著名历史学家保罗·约翰逊经典作品，冲破柏拉图与色诺芬的围城，还原历史上真实的苏格拉底，描绘我们这一代人的苏格拉底、每个人心中的苏格拉底。大学问出品 · 一部...\n纸质版 40.94元\n悉达多 : 一首印度的诗\n[德] 赫尔曼·黑塞 / 姜乙 / 天津人民出版社 / 2017-1 / 32.00元\n9.3 (86461人评价)\n《悉达多》并非是佛陀的故事，它讲述了一个人的一生，千万寻常人亦会经历的一生。 意气风发的少年郎，常认为自己是被命运选中的人。抛下过去，随了跌跌撞撞的步伐，找...\n纸质版 32.00元\n去看电子版\n将熟悉变为陌生 : 与齐格蒙特·鲍曼对谈\n[英] 齐格蒙·鲍曼、[瑞士] 彼得·哈夫纳 / 王立秋 / 南京大学出版社 / 2023-8-6 / 68.00元\n8.9 (1289人评价)\n“原来的做事方式全部失效，新的方式却没有被发明出来。这就是我们今天的处境。” * ◎ 《工作、消费主义和新穷人》作者，鲍曼在世最后访谈。 ◎ 当代极具影响力...\n纸质版 55.10元\n西方哲学史（第9版）\n(美) 撒穆尔·伊诺克·斯通普夫、(美) 詹姆斯·菲泽 / 邓晓芒、匡宏、等 / 北京联合出版公司 / 2019-8 / 99.80元\n9.2 (2905人评价)\n畅销五十余载而不衰，备受好评的西哲史教材全新再版 通俗易懂的历史梳理，从古典文籍到当代前沿一应俱全 ◎ 编辑推荐 ☆自1966年初版至今最新修订版 ☆西方哲...\n纸质版 79.00元\n真实与虚拟 : 后真相时代的哲学\n金观涛 / 中信出版社 / 2023-7 / 98元\n9.0 (156人评价)\n这是一个后真相时代，我们对于何为真实的判断暧昧晦暗。现代社会庞大的信息数据网络，除了如同迷魂阵令人难辨真假，也如同牢笼将我们封锁其中。回顾来路，20世纪的变...\n纸质版 58.70元\n去看电子版\n刘擎西方现代思想讲义\n刘擎 / 新星出版社 / 2021-1 / 79.00元\n9.2 (33298人评价)\n人生的意义，人们向往的自由和公平的价值，人类文明的复杂冲突与未来趋势……这些让你困惑的大小问题，过去也困扰过韦伯、尼采、萨特等杰出的头脑。他们尽最大努力做出...\n纸质版 56.40元\n哲学之旅 : 一种互动性探究\n(美) 威廉·F. 劳海德 / 张祖辽、杨东东 / 东方出版中心 / 2023-9 / 160.00元\n8.4 (21人评价)\n《哲学之旅：一种互动性探究》是哲学史家威廉·F. 劳海德的代表作，面世后反响极佳，目前已出到第7版。本书是一部富有趣味性、互动性，对读者，尤其是初学者非常友...\n纸质版 132.30元\n存在主义咖啡馆 : 自由、存在和杏子鸡尾酒\n[英] 莎拉·贝克韦尔 / 沈敏一 / 北京联合出版公司 / 2017-12-1 / 88.00\n8.6 (15914人评价)\n巴黎，1933年…… 三位朋友正坐在蒙帕纳斯大道上的煤气灯酒吧里喝着杏子鸡尾酒。其中一个叫雷蒙·阿隆的年轻哲学家，正在向同为哲学家的让-保罗·萨特和西蒙娜·...\n纸质版 84.40元\n去看电子版\n被讨厌的勇气\n(日) 岸见一郎，古贺史健 / 渠海霞 / 机械工业出版社 / 2021-1 / 55\n8.3 (16557人评价)\n本书用“青年与哲人的对话”这一故事形式总结了与弗洛伊德、荣格并称为“心理学三大巨头”的阿尔弗雷德·阿德勒的思想(阿德勒心理学)。 风靡欧美的阿德勒心理学对于...\n去看电子版\n大问题 : 简明哲学导论\n[美] 罗伯特·所罗门、凯思林•希金斯 / 张卜天 / 广西师范大学出版社 / 2014-12 / 65.00\n9.3 (8168人评价)\n本书的目的就是引导读者进入真正思考的大门。罗伯特•所罗门教授尤以擅长授课和写作清晰晓畅著称，他不像一般哲学导论著作那样按照事件发生的顺序罗列哲学史上的一些观...\n理想国\n[古希腊] 柏拉图 / 郭斌和、张竹明 / 商务印书馆 / 1986-8 / 28.00元\n8.8 (35944人评价)\n《理想国》涉及柏拉图思想体系的各个方面，包括哲学、伦理、教育、文艺、政治等内容，主要是探讨理想国家的问题。 《理想国》一书是柏拉图的一篇重要对话录，对话录里...\n纸质版 36.00元\n思想之诗 : 从希腊主义到策兰\n[美]乔治·斯坦纳 / 远子 / 广西师范 ...

# %%
# 只要书籍信息：调用items获得生成器
doc.items('.subject-item')    # 书的唯一定位标签为 .subject_item
# Out:
# <generator object PyQuery.items at 0x000001A4D80AFAE0>

# %%
for book in doc.items('.subject-item'):
#     print(type(book))   # 有20本
    print(book)       # 查看这20本书的信息
# Out:
# <li class="subject-item">
#     <div class="pic">
#       <a class="nbg" href="https://book.douban.com/subject/36518908/" onclick="moreurl(this,{i:'0',query:'',subject_id:'36518908',from:'book_subject_search'})">
#         <img class="" src="https://img9.doubanio.com/view/subject/s/public/s34628355.jpg" width="90"/>
#       </a>
#     </div>
#     <div class="info">
#       <h2 class="">
#
#
#   <a href="https://book.douban.com/subject/36518908/" title="苏格拉底" onclick="moreurl(this,{i:'0',query:'',subject_id:'36518908',from:'book_subject_search'})">
#
#     苏格拉底
#
#
#
#       <span style="font-size:12px;"> : 我们的同时代人 </span>
#
#   </a>
#
#       </h2>
#       <div class="pub">
#
#
#   [英] 保罗·约翰逊 / 郝苑 / 广西师范大学出版社 / 2023-9 / 58
#
#       </div>
#
#
#
#
#
#
#   <div class="star clearfix">
#         <span class="allstar45"/>
#         <span class="rating_nums">9.0</span>
#
#     <span class="pl">
#         (71人评价)
#     </span>
#   </div>
#
#
#
#
#
#
#
#     <p>著名历史学家保罗·约翰逊经典作品，冲破柏拉图与色诺芬的围城，还原历史上真实的苏格拉底，描绘我们这一代人的苏格拉底、每个人心中的苏格拉底。大学问出品
# ·
# 一部... </p>
#
#
#
#
#
#
#       <div class="ft">
#
#   <div class="collect-info">
#   </div>
#
#
#           <div class="cart-actions">
#
#
#
#
#     <span class="buy-info">
#       <a href="https://book.douban.com/subject/36518908/buylinks">
#         纸质版 40.94元
#       </a>
#     </span>
#
#           </div>
#
#
#
#
#
#       </div>
#
#     </div>
#   </li>
#
#
#
#
#
# <li class="subject-item">
#     <div class="pic">
#       <a class="nbg" href="https://book.douban.com/subject/26980487/" onclick="moreurl(this,{i:'1',query:'',subject_id:'26980487',from:'book_subject_search'})">
#         <img class="" src="https://img1.doubanio.com/view/subject/s/public/s29396368.jpg" width="90"/>
#       </a>
#     </div>
#     <div class="info">
#       <h2 class="">
#
#
#   <a href="https://book.douban.com/subject/26980487/" title="悉达多" onclick="moreurl(this,{i:'1',query:'',subject_id:'26980487',from:'book_subject_search'})">
#
#     悉达多
#
#
#
#       <span style="font-size:12px;"> : 一首印度的诗 </span>
#
#   </a>
#
#       </h2>
#       <div class="pub">
#
#
#   [德] 赫尔曼·黑塞 / 姜乙 / 天津人民出版社 / 2017-1 / 32.00元
#
#       </div>
#
#
#
#
#
#
#   <div class="star clearfix">
#         <span class="allstar45"/>
#         <span class="rating_nums">9.3</span>
#
#     <span class="pl">
#         (86461人评价)
#     </span>
#   </div>
#
#
#
#
#
#
#
#     <p>《悉达多》并非是佛陀的故事，它讲述了一个人的一生，千万寻常人亦会经历的一生。
# 意气风发的少年郎，常认为自己是被命运选中的人。抛下过去，随了跌跌撞撞的步伐，找... </p>
#
#
#
#
#
#
#       <div class="ft">
#
#   <div class="collect-info">
#   </div>
#
#
#           <div class="cart-actions">
#
#
#
#
#     <span class="buy-info">
#       <a href="https://book.douban.com/subject/26980487/buylinks">
#         纸质版 32.00元
#       </a>
#     </span>
#
#           </div>
#
#
#
#
#
#
#   <div class="ebook-link">
#     <a target="_blank" href="https://read.douban.com/ebook/31953088/?dcs=tag-buylink&amp;dcm=douban&amp;dct=26980487">去看电子版</a>
#   </div>
#
#
#
#       </div>
#
#     </div>
#   </li>
#
#
#
#
#
# <li class="subject-item">
#     <div class="pic">
#       <a class="nbg" href="https://book.douban.com/subject/36409321/" onclick="moreurl(this,{i:'2',query:'',subject_id:'36409321',from:'book_subject_search'})">
#         <img class="" src="https://img2.doubanio.com/view/subject/s/public/s34593512.jpg" width="90"/>
#       </a>
#     </div>
#     <div class="info">
#       <h2 class="">
#
#
#   <a href="https://book.douban.com/subject/36409321/" title="将熟悉变为陌生" onclick="moreurl(this,{i:'2',query:'',subject_id:'36409321',from:'book_subject_search'})">
#
#     将熟悉变为陌生
#
#
#
#       <span style="font-size:12px;"> : 与齐格蒙特·鲍曼对谈 </span>
#
#   </a>
#
#       </h2>
#       <div class="pub">
#
#
#   [英] 齐格蒙·鲍曼、[瑞士] 彼得·哈夫纳 / 王立秋 / 南京大学出版社 / 2023-8-6 / 68.00元
#
#       </div>
#
#
#
#
#
#
#   <div class="star clearfix">
#         <span class="allstar45"/>
#         <span class="rating_nums">8.9</span>
#
#     <span class="pl">
#         (1289人评价)
#     </span>
#   </div>
#
#
#
#
#
#
#
#     <p>“原来的做事方式全部失效，新的方式却没有被发明出来。这就是我们今天的处境。”
# *
# ◎ 《工作、消费主义和新穷人》作者，鲍曼在世最后访谈。
# ◎ 当代极具影响力... </p>
#
#
#
#
#
#
#       <div class="ft">
#
#   <div class="collect-info">
#   </div>
#
#
#           <div class="cart-actions">
#
#
#
#
#     <span class="buy-info">
#       <a href="https://book.douban.com/subject/36409321/buylinks">
#         纸质版 55.10元
#       </a>
#     </span>
#
#           </div>
#
#
#
#
#
#       </div>
#
#     </div>
#   </li>
#
#
#
#
#
# <li class="subject-item">
#     <div class="pic">
#       <a class="nbg" href="https://book.douban.com/subject/34447865/" onclick="moreurl(this,{i:'3',query:'',subject_id:'34447865',from:'book_subject_search'})">
#         <img class="" src="https://img1.doubanio.com/view/subject/s/public/s33438650.jpg" width="90"/>
#       </a>
#     </div>
#     <div class="info">
#       <h2 class="">
#
#
#   <a href="https://book.douban.com/subject/34447865/" title="西方哲学史（第9版）" onclick="moreurl(this,{i:'3',query:'',subject_id:'34447865',from:'book_subject_search'})">
#
#     西方哲学史（第9版）
#
#
#
#
#   </a>
#
#       </h2>
#       <div class="pub">
#
#
#   (美) 撒穆尔·伊诺克·斯通普夫、(美) 詹姆斯·菲泽 / 邓晓芒、匡宏、等 / 北京联合出版公司 / 2019-8 / 99.80元
#
#       </div>
#
#
#
#
#
#
#   <div class="star clearfix">
#         <span class="allstar45"/>
#         <span class="rating_nums">9.2</span>
#
#     <span class="pl">
#         (2905人评价)
#     </span>
#   </div>
#
#
#
#
#
#
#
#     <p>畅销五十余载而不衰，备受好评的西哲史教材全新再版
# 通俗易懂的历史梳理，从古典文籍到当代前沿一应俱全
# ◎ 编辑推荐
# ☆自1966年初版至今最新修订版
# ☆西方哲... </p>
#
#
#
#
#
#
#       <div class="ft">
#
#   <div class="collect-info">
#   </div>
#
#
#           <div class="cart-actions">
#
#
#
#
#     <span class="buy-info">
#       <a href="https://book.douban.com/subject/34447865/buylinks">
#         纸质版 79.00元
#       </a>
#     </span>
#
#           </div>
#
#
#
#
#
#       </div>
#
#     </div>
#   </li>
#
#
#
#
#
# <li class="subject-item">
#     <div class="pic">
#       <a class="nbg" href="https://book.douban.com/subject/36392187/" onclick="moreurl(this,{i:'4',query:'',subject_id:'36392187',from:'book_subject_search'})">
#         <img class="" src="https://img9.doubanio.com/view/subject/s/public/s34579844.jpg" width="90"/>
#       </a>
#     </div>
#     <div class="info">
#       <h2 class="">
#
#
#   <a href="https://book.douban.com/subject/36392187/" title="真实与虚拟" onclick="moreurl(this,{i:'4',query:'',subject_id:'36392187',from:'book_subject_search'})">
#
#     真实与虚拟
#
#
#
#       <span style="font-size:12px;"> : 后真相时代的哲学 </span>
#
#   </a>
#
#       </h2>
#       <div class="pub">
#
#
#   金观涛 / 中信出版社 / 2023-7 / 98元
#
#       </div>
#
#
#
#
#
#
#   <div class="star clearfix">
#         <span class="allstar45"/>
#         <span class="rating_nums">9.0</span>
#
#     <span class="pl">
#         (156人评价)
#     </span>
#   </div>
#
#
#
#
#
#
#
#     <p>这是一个后真相时代，我们对于何为真实的判断暧昧晦暗。现代社会庞大的信息数据网络，除了如同迷魂阵令人难辨真假，也如同牢笼将我们封锁其中。回顾来路，20世纪的变... </p>
#
#
#
#
#
#
#       <div class="ft">
#
#   <div class="collect-info">
#   </div>
#
#
#           <div class="cart-actions">
#
#
#
#
#     <span class="buy-info">
#       <a href="https://book.douban.com/subject/36392187/buylinks">
#         纸质版 58.70元
#       </a>
#     </span>
#
#           </div>
#
#
#
#
#
#
#   <div class="ebook-link">
#     <a target="_blank" href="https://read.douban.com/ebook/441064897/?dcs=tag-buylink&amp;dcm=douban&amp;dct=36392187">去看电子版</a>
#   </div>
#
#
#
#       </div>
#
#     </div>
#   </li>
#
#
#
#
#
# <li class="subject-item">
#     <div class="pic">
#       <a class="nbg" href="https://book.douban.com/subject/35313227/" onclick="moreurl(this,{i:'5',query:'',subject_id:'35313227',from:'book_subject_search'})">
#         <img class="" src="https://img2.doubanio.com/view/subject/s/public/s33802981.jpg" width="90"/>
#       </a>
#     </div>
#     <div class="info">
#       <h2 class="">
#
#
#   <a href="https://book.douban.com/subject/35313227/" title="刘擎西方现代思想讲义" onclick="moreurl(this,{i:'5',query:'',subject_id:'35313227',from:'book_subject_search'})">
#
#     刘擎西方现代思想讲义
#
#
#
#
#   </a>
#
#       </h2>
#       <div class="pub">
#
#
#   刘擎 / 新星出版社 / 2021-1 / 79.00元
#
#       </div>
#
#
#
#
#
#
#   <div class="star clearfix">
#         <span class="allstar45"/>
#         <span class="rating_nums">9.2</span>
#
#     <span class="pl">
#         (33298人评价)
#     </span>
#   </div>
#
#
#
#
#
#
#
#     <p>人生的意义，人们向往的自由和公平的价值，人类文明的复杂冲突与未来趋势……这些让你困惑的大小问题，过去也困扰过韦伯、尼采、萨特等杰出的头脑。他们尽最大努力做出... </p>
#
#
#
#
#
#
#       <div class="ft">
#
#   <div class="collect-info">
#   </div>
#
#
#           <div class="cart-actions">
#
#
#
#
#     <span class="buy-info">
#       <a href="https://book.douban.com/subject/35313227/buylinks">
#         纸质版 56.40元
#       </a>
#     </span>
#
#           </div>
#
#
#
#
#
#       </div>
#
#     </div>
#   </li>
#
#
#
#
#
# <li class="subject-item">
#     <div class="pic">
#       <a class="nbg" href="https://book.douban.com/subject/36490712/" onclick="moreurl(this,{i:'6',query:'',subject_id:'36490712',from:'book_subject_search'})">
#         <img class="" src="https://img2.doubanio.com/view/subject/s/public/s34675022.jpg" width="90"/>
#       </a>
#     </div>
#     <div class="info">
#       <h2 class="">
#
#
#   <a href="https://book.douban.com/subject/36490712/" title="哲学之旅" onclick="moreurl(this,{i:'6',query:'',subject_id:'36490712',from:'book_subject_search'})">
#
#     哲学之旅
#
#
#
#       <span style="font-size:12px;"> : 一种互动性探究 </span>
#
#   </a>
#
#       </h2>
#       <div class="pub">
#
#
#   (美) 威廉·F. 劳海德 / 张祖辽、杨东东 / 东方出版中心 / 2023-9 / 160.00元
#
#       </div>
#
#
#
#
#
#
#   <div class="star clearfix">
#         <span class="allstar40"/>
#         <span class="rating_nums">8.4</span>
#
#     <span class="pl">
#         (21人评价)
#     </span>
#   </div>
#
#
#
#
#
#
#
#     <p>《哲学之旅：一种互动性探究》是哲学史家威廉·F. 劳海德的代表作，面世后反响极佳，目前已出到第7版。本书是一部富有趣味性、互动性，对读者，尤其是初学者非常友... </p>
#
#
#
#
#
#
#       <div class="ft">
#
#   <div class="collect-info">
#   </div>
#
#
#           <div class="cart-actions">
#
#
#
#
#     <span class="buy-info">
#       <a href="https://book.douban.com/subject/36490712/buylinks">
#         纸质版 132.30元
#       </a>
#     </span>
#
#           </div>
#
#
#
#
#
#       </div>
#
#     </div>
#   </li>
#
#
#
#
#
# <li class="subject-item">
#     <div class="pic">
#       <a class="nbg" href="https://book.douban.com/subject/27170538/" onclick="moreurl(this,{i:'7',query:'',subject_id:'27170538',from:'book_subject_search'})">
#         <img class="" src="https://img2.doubanio.com/view/subject/s/public/s29675043.jpg" width="90"/>
#       </a>
#     </div>
#     <div class="info">
#       <h2 class="">
#
#
#   <a href="https://book.douban.com/subject/27170538/" title="存在主义咖啡馆" onclick="moreurl(this,{i:'7',query:'',subject_id:'27170538',from:'book_subject_search'})">
#
#     存在主义咖啡馆
#
#
#
#       <span style="font-size:12px;"> : 自由、存在和杏子鸡尾酒 </span>
#
#   </a>
#
#       </h2>
#       <div class="pub">
#
#
#   [英] 莎拉·贝克韦尔 / 沈敏一 / 北京联合出版公司 / 2017-12-1 / 88.00
#
#       </div>
#
#
#
#
#
#
#   <div class="star clearfix">
#         <span class="allstar45"/>
#         <span class="rating_nums">8.6</span>
#
#     <span class="pl">
#         (15914人评价)
#     </span>
#   </div>
#
#
#
#
#
#
#
#     <p>巴黎，1933年……
# 三位朋友正坐在蒙帕纳斯大道上的煤气灯酒吧里喝着杏子鸡尾酒。其中一个叫雷蒙·阿隆的年轻哲学家，正在向同为哲学家的让-保罗·萨特和西蒙娜·... </p>
#
#
#
#
#
#
#       <div class="ft">
#
#   <div class="collect-info">
#   </div>
#
#
#           <div class="cart-actions">
#
#
#
#
#     <span class="buy-info">
#       <a href="https://book.douban.com/subject/27170538/buylinks">
#         纸质版 84.40元
#       </a>
#     </span>
#
#           </div>
#
#
#
#
#
#
#   <div class="ebook-link">
#     <a target="_blank" href="https://read.douban.com/ebook/117501946/?dcs=tag-buylink&amp;dcm=douban&amp;dct=27170538">去看电子版</a>
#   </div>
#
#
#
#       </div>
#
#     </div>
#   </li>
#
#
#
#
#
# <li class="subject-item">
#     <div class="pic">
#       <a class="nbg" href="https://book.douban.com/subject/36150914/" onclick="moreurl(this,{i:'8',query:'',subject_id:'36150914',from:'book_subject_search'})">
#         <img class="" src="https://img9.doubanio.com/view/subject/s/public/s34348664.jpg" width="90"/>
#       </a>
#     </div>
#     <div class="info">
#       <h2 class="">
#
#
#   <a href="https://book.douban.com/subject/36150914/" title="被讨厌的勇气" onclick="moreurl(this,{i:'8',query:'',subject_id:'36150914',from:'book_subject_search'})">
#
#     被讨厌的勇气
#
#
#
#
#   </a>
#
#       </h2>
#       <div class="pub">
#
#
#   (日) 岸见一郎，古贺史健 / 渠海霞 / 机械工业出版社 / 2021-1 / 55
#
#       </div>
#
#
#
#
#
#
#   <div class="star clearfix">
#         <span class="allstar40"/>
#         <span class="rating_nums">8.3</span>
#
#     <span class="pl">
#         (16557人评价)
#     </span>
#   </div>
#
#
#
#
#
#
#
#     <p>本书用“青年与哲人的对话”这一故事形式总结了与弗洛伊德、荣格并称为“心理学三大巨头”的阿尔弗雷德·阿德勒的思想(阿德勒心理学)。
# 风靡欧美的阿德勒心理学对于... </p>
#
#
#
#
#
#
#       <div class="ft">
#
#   <div class="collect-info">
#   </div>
#
#
#           <div class="cart-actions">
#
#
#
#
#
#           </div>
#
#
#
#
#
#
#   <div class="ebook-link">
#     <a target="_blank" href="https://read.douban.com/ebook/423264453/?dcs=tag-buylink&amp;dcm=douban&amp;dct=36150914">去看电子版</a>
#   </div>
#
#
#
#       </div>
#
#     </div>
#   </li>
#
#
#
#
#
# <li class="subject-item">
#     <div class="pic">
#       <a class="nbg" href="https://book.douban.com/subject/25961458/" onclick="moreurl(this,{i:'9',query:'',subject_id:'25961458',from:'book_subject_search'})">
#         <img class="" src="https://img1.doubanio.com/view/subject/s/public/s29144990.jpg" width="90"/>
#       </a>
#     </div>
#     <div class="info">
#       <h2 class="">
#
#
#   <a href="https://book.douban.com/subject/25961458/" title="大问题" onclick="moreurl(this,{i:'9',query:'',subject_id:'25961458',from:'book_subject_search'})">
#
#     大问题
#
#
#
#       <span style="font-size:12px;"> : 简明哲学导论 </span>
#
#   </a>
#
#       </h2>
#       <div class="pub">
#
#
#   [美] 罗伯特·所罗门、凯思林•希金斯 / 张卜天 / 广西师范大学出版社 / 2014-12 / 65.00
#
#       </div>
#
#
#
#
#
#
#   <div class="star clearfix">
#         <span class="allstar45"/>
#         <span class="rating_nums">9.3</span>
#
#     <span class="pl">
#         (8168人评价)
#     </span>
#   </div>
#
#
#
#
#
#
#
#     <p>本书的目的就是引导读者进入真正思考的大门。罗伯特•所罗门教授尤以擅长授课和写作清晰晓畅著称，他不像一般哲学导论著作那样按照事件发生的顺序罗列哲学史上的一些观... </p>
#
#
#
#
#
#
#       <div class="ft">
#
#   <div class="collect-info">
#   </div>
#
#
#           <div class="cart-actions">
#
#
#
#
#
#           </div>
#
#
#
#
#
#       </div>
#
#     </div>
#   </li>
#
#
#
#
#
# <li class="subject-item">
#     <div class="pic">
#       <a class="nbg" href="https://book.douban.com/subject/1004821/" onclick="moreurl(this,{i:'10',query:'',subject_id:'1004821',from:'book_subject_search'})">
#         <img class="" src="https://img1.doubanio.com/view/subject/s/public/s34157889.jpg" width="90"/>
#       </a>
#     </div>
#     <div class="info">
#       <h2 class="">
#
#
#   <a href="https://book.douban.com/subject/1004821/" title="理想国" onclick="moreurl(this,{i:'10',query:'',subject_id:'1004821',from:'book_subject_search'})">
#
#     理想国
#
#
#
#
#   </a>
#
#       </h2>
#       <div class="pub">
#
#
#   [古希腊] 柏拉图 / 郭斌和、张竹明 / 商务印书馆 / 1986-8 / 28.00元
#
#       </div>
#
#
#
#
#
#
#   <div class="star clearfix">
#         <span class="allstar45"/>
#         <span class="rating_nums">8.8</span>
#
#     <span class="pl">
#         (35944人评价)
#     </span>
#   </div>
#
#
#
#
#
#
#
#     <p>《理想国》涉及柏拉图思想体系的各个方面，包括哲学、伦理、教育、文艺、政治等内容，主要是探讨理想国家的问题。
# 《理想国》一书是柏拉图的一篇重要对话录，对话录里... </p>
#
#
#
#
#
#
#       <div class="ft">
#
#   <div class="collect-info">
#   </div>
#
#
#           <div class="cart-actions">
#
#
#
#
#     <span class="buy-info">
#       <a href="https://book.douban.com/subject/1004821/buylinks">
#         纸质版 36.00元
#       </a>
#     </span>
#
#           </div>
#
#
#
#
#
#       </div>
#
#     </div>
#   </li>
#
#
#
#
#
# <li class="subject-item">
#     <div class="pic">
#       <a class="nbg" href="https://book.douban.com/subject/36445280/" onclick="moreurl(this,{i:'11',query:'',subject_id:'36445280',from:'book_subject_search'})">
#         <img class="" src="https://img1.doubanio.com/view/subject/s/public/s34562738.jpg" width="90"/>
#       </a>
#     </div>
#     <div class="info">
#       <h2 class="">
#
#
#   <a href="https://book.douban.com/subject/36445280/" title="思想之诗" onclick="moreurl(this,{i:'11',query:'',subject_id:'36445280',from:'book_subject_search'})">
#
#     思想之诗
#
#
#
#       <span style="font-size:12px;"> : 从希腊主义到策兰 </span>
#
#   </a>
#
#       </h2>
#       <div class="pub">
#
#
#   [美]乔治·斯坦纳 / 远子 / 广西师范大学出版社 / 2023-8 / 79.00元
#
#       </div>
#
#
#
#
#
#
#   <div class="star clearfix">
#         <span class="allstar45"/>
#         <span class="rating_nums">9.2</span>
#
#     <span class="pl">
#         (89人评价)
#     </span>
#   </div>
#
#
#
#
#
#
#
#     <p>人文主义者斯坦纳的诗与思溯源之旅
# 细细拆解哲学与文学的无穷缠结
# 【内容简介】
# 斯坦纳认为，整个西方哲学史中藏着一条文学的暗线，所有思想论说都蕴含风格、形象、... </p>
#
#
#
#
#
#
#       <div class="ft">
#
#   <div class="collect-info">
#   </div>
#
#
#           <div class="cart-actions">
#
#
#
#
#     <span class="buy-info">
#       <a href="https://book.douban.com/subject/36445280/buylinks">
#         纸质版 79.00元
#       </a>
#     </span>
#
#           </div>
#
#
#
#
#
#       </div>
#
#     </div>
#   </li>
#
#
#
#
#
# <li class="subject-item">
#     <div class="pic">
#       <a class="nbg" href="https://book.douban.com/subject/35900190/" onclick="moreurl(this,{i:'12',query:'',subject_id:'35900190',from:'book_subject_search'})">
#         <img class="" src="https://img1.doubanio.com/view/subject/s/public/s34219967.jpg" width="90"/>
#       </a>
#     </div>
#     <div class="info">
#       <h2 class="">
#
#
#   <a href="https://book.douban.com/subject/35900190/" title="在绝望之巅" onclick="moreurl(this,{i:'12',query:'',subject_id:'35900190',from:'book_subject_search'})">
#
#     在绝望之巅
#
#
#
#
#   </a>
#
#       </h2>
#       <div class="pub">
#
#
#   [法国] E·M·齐奥朗 / 唐江 / 北京联合出版公司 / 2022-6 / 49.80
#
#       </div>
#
#
#
#
#
#
#   <div class="star clearfix">
#         <span class="allstar40"/>
#         <span class="rating_nums">8.3</span>
#
#     <span class="pl">
#         (6514人评价)
#     </span>
#   </div>
#
#
#
#
#
#
#
#     <p>◎“二十世纪的尼采”、现代欧洲最伟大的哲学家之一
# ◎E.M.齐奥朗初试啼声之作 中文简体版首次译介
# ★
# 在绝望之巅挣扎，燃起超脱生死的激情
# 将眼泪变成思想，... </p>
#
#
#
#
#
#
#       <div class="ft">
#
#   <div class="collect-info">
#   </div>
#
#
#           <div class="cart-actions">
#
#
#
#
#     <span class="buy-info">
#       <a href="https://book.douban.com/subject/35900190/buylinks">
#         纸质版 49.80元
#       </a>
#     </span>
#
#           </div>
#
#
#
#
#
#
#   <div class="ebook-link">
#     <a target="_blank" href="https://read.douban.com/ebook/414652366/?dcs=tag-buylink&amp;dcm=douban&amp;dct=35900190">去看电子版</a>
#   </div>
#
#
#
#       </div>
#
#     </div>
#   </li>
#
#
#
#
#
# <li class="subject-item">
#     <div class="pic">
#       <a class="nbg" href="https://book.douban.com/subject/36361955/" onclick="moreurl(this,{i:'13',query:'',subject_id:'36361955',from:'book_subject_search'})">
#         <img class="" src="https://img9.doubanio.com/view/subject/s/public/s34595866.jpg" width="90"/>
#       </a>
#     </div>
#     <div class="info">
#       <h2 class="">
#
#
#   <a href="https://book.douban.com/subject/36361955/" title="供词与放逐" onclick="moreurl(this,{i:'13',query:'',subject_id:'36361955',from:'book_subject_search'})">
#
#     供词与放逐
#
#
#
#
#   </a>
#
#       </h2>
#       <div class="pub">
#
#
#   [法]E.M.齐奥朗 / 赵苓岑 / 广西师范大学出版社 / 2023-8 / 39.8元
#
#       </div>
#
#
#
#
#
#
#   <div class="star clearfix">
#         <span class="allstar40"/>
#         <span class="rating_nums">8.3</span>
#
#     <span class="pl">
#         (302人评价)
#     </span>
#   </div>
#
#
#
#
#
#
#
#     <p>【编辑推荐】
# ⭐ “丧”系哲学家·重度失眠病人·最著名的怀疑论者——齐奥朗
# 他是哲学家E.M.齐奥朗，反叛是他的代名词，
# 他与伊利亚德、尤内斯库并称“罗马尼... </p>
#
#
#
#
#
#
#       <div class="ft">
#
#   <div class="collect-info">
#   </div>
#
#
#           <div class="cart-actions">
#
#
#
#
#     <span class="buy-info">
#       <a href="https://book.douban.com/subject/36361955/buylinks">
#         纸质版 29.80元
#       </a>
#     </span>
#
#           </div>
#
#
#
#
#
#       </div>
#
#     </div>
#   </li>
#
#
#
#
#
# <li class="subject-item">
#     <div class="pic">
#       <a class="nbg" href="https://book.douban.com/subject/36361959/" onclick="moreurl(this,{i:'14',query:'',subject_id:'36361959',from:'book_subject_search'})">
#         <img class="" src="https://img1.doubanio.com/view/subject/s/public/s34595870.jpg" width="90"/>
#       </a>
#     </div>
#     <div class="info">
#       <h2 class="">
#
#
#   <a href="https://book.douban.com/subject/36361959/" title="苦论" onclick="moreurl(this,{i:'14',query:'',subject_id:'36361959',from:'book_subject_search'})">
#
#     苦论
#
#
#
#
#   </a>
#
#       </h2>
#       <div class="pub">
#
#
#   [法国] E.M.齐奥朗 / 蔡羽婷 / 广西师范大学出版社 / 2023-8 / 39.8元
#
#       </div>
#
#
#
#
#
#
#   <div class="star clearfix">
#         <span class="allstar40"/>
#         <span class="rating_nums">7.9</span>
#
#     <span class="pl">
#         (428人评价)
#     </span>
#   </div>
#
#
#
#
#
#
#
#     <p>【编辑推荐】
# ⭐危险哲学家齐奥朗，人生首部短句集！在法国最畅销、最受欢迎之作
# “与齐奥朗交朋友是有危险的，但这种危险能让你活着。”
# 危险哲学家齐奥朗，用“碎... </p>
#
#
#
#
#
#
#       <div class="ft">
#
#   <div class="collect-info">
#   </div>
#
#
#           <div class="cart-actions">
#
#
#
#
#     <span class="buy-info">
#       <a href="https://book.douban.com/subject/36361959/buylinks">
#         纸质版 29.80元
#       </a>
#     </span>
#
#           </div>
#
#
#
#
#
#       </div>
#
#     </div>
#   </li>
#
#
#
#
#
# <li class="subject-item">
#     <div class="pic">
#       <a class="nbg" href="https://book.douban.com/subject/30136393/" onclick="moreurl(this,{i:'15',query:'',subject_id:'30136393',from:'book_subject_search'})">
#         <img class="" src="https://img2.doubanio.com/view/subject/s/public/s33823033.jpg" width="90"/>
#       </a>
#     </div>
#     <div class="info">
#       <h2 class="">
#
#
#   <a href="https://book.douban.com/subject/30136393/" title="做哲学" onclick="moreurl(this,{i:'15',query:'',subject_id:'30136393',from:'book_subject_search'})">
#
#     做哲学
#
#
#
#       <span style="font-size:12px;"> : 88个思想实验中的哲学导论 </span>
#
#   </a>
#
#       </h2>
#       <div class="pub">
#
#
#   [美] 小西奥多·希克、刘易斯·沃恩 / 柴伟佳、龚皓 / 北京联合出版公司 / 2018-8 / 118.00元
#
#       </div>
#
#
#
#
#
#
#   <div class="star clearfix">
#         <span class="allstar45"/>
#         <span class="rating_nums">9.3</span>
#
#     <span class="pl">
#         (812人评价)
#     </span>
#   </div>
#
#
#
#
#
#
#
#     <p>你从未读到过的哲学导论
# 磨砺审辩性思维技巧的方法指南
# 于哲学实践中锤炼理论想象力和逻辑分析能力
# 用思想实验不停挑战并重塑你对世界的认知和判断
# …………………... </p>
#
#
#
#
#
#
#       <div class="ft">
#
#   <div class="collect-info">
#   </div>
#
#
#           <div class="cart-actions">
#
#
#
#
#     <span class="buy-info">
#       <a href="https://book.douban.com/subject/30136393/buylinks">
#         纸质版 118.00元
#       </a>
#     </span>
#
#           </div>
#
#
#
#
#
#       </div>
#
#     </div>
#   </li>
#
#
#
#
#
# <li class="subject-item">
#     <div class="pic">
#       <a class="nbg" href="https://book.douban.com/subject/33442259/" onclick="moreurl(this,{i:'16',query:'',subject_id:'33442259',from:'book_subject_search'})">
#         <img class="" src="https://img2.doubanio.com/view/subject/s/public/s33300502.jpg" width="90"/>
#       </a>
#     </div>
#     <div class="info">
#       <h2 class="">
#
#
#   <a href="https://book.douban.com/subject/33442259/" title="倦怠社会" onclick="moreurl(this,{i:'16',query:'',subject_id:'33442259',from:'book_subject_search'})">
#
#     倦怠社会
#
#
#
#
#   </a>
#
#       </h2>
#       <div class="pub">
#
#
#   [德] 韩炳哲 / 王一力 / 中信出版集团 / 2019-6-1 / 35.00元
#
#       </div>
#
#
#
#
#
#
#   <div class="star clearfix">
#         <span class="allstar40"/>
#         <span class="rating_nums">7.8</span>
#
#     <span class="pl">
#         (12272人评价)
#     </span>
#   </div>
#
#
#
#
#
#
#
#     <p>否定性的社会已经消失，取而代之的是充溢着积极性的社会。
# 从这一范式转移出发，韩炳哲展示了当今社会的病理形态，其中包括忧郁症、注意力缺乏症、过劳症等精神疾病。... </p>
#
#
#
#
#
#
#       <div class="ft">
#
#   <div class="collect-info">
#   </div>
#
#
#           <div class="cart-actions">
#
#
#
#
#     <span class="buy-info">
#       <a href="https://book.douban.com/subject/33442259/buylinks">
#         纸质版 22.80元
#       </a>
#     </span>
#
#           </div>
#
#
#
#
#
#
#   <div class="ebook-link">
#     <a target="_blank" href="https://read.douban.com/ebook/121967845/?dcs=tag-buylink&amp;dcm=douban&amp;dct=33442259">去看电子版</a>
#   </div>
#
#
#
#       </div>
#
#     </div>
#   </li>
#
#
#
#
#
# <li class="subject-item">
#     <div class="pic">
#       <a class="nbg" href="https://book.douban.com/subject/36464124/" onclick="moreurl(this,{i:'17',query:'',subject_id:'36464124',from:'book_subject_search'})">
#         <img class="" src="https://img1.doubanio.com/view/subject/s/public/s34637350.jpg" width="90"/>
#       </a>
#     </div>
#     <div class="info">
#       <h2 class="">
#
#
#   <a href="https://book.douban.com/subject/36464124/" title="第三次观念飞跃" onclick="moreurl(this,{i:'17',query:'',subject_id:'36464124',from:'book_subject_search'})">
#
#     第三次观念飞跃
#
#
#
#       <span style="font-size:12px;"> : 世界冲突的根源与解决之道 </span>
#
#   </a>
#
#       </h2>
#       <div class="pub">
#
#
#   [美]琳达·扎格泽博斯基 / 孙天 / 广西师范大学出版社 / 2023-10 / 88.00元
#
#       </div>
#
#
#
#
#
#
#   <div class="star clearfix">
#         <span class="allstar45"/>
#         <span class="rating_nums">8.5</span>
#
#     <span class="pl">
#         (51人评价)
#     </span>
#   </div>
#
#
#
#
#
#
#
#     <p>环境保护、胎儿权利、婚姻定义、身份认同、移民问题、言论边界……
# “世界”与“自我”无法兼容的时代，我们如何自处？
# 探寻政治与道德分歧的深层根源，一场针对主体... </p>
#
#
#
#
#
#
#       <div class="ft">
#
#   <div class="collect-info">
#   </div>
#
#
#           <div class="cart-actions">
#
#
#
#
#     <span class="buy-info">
#       <a href="https://book.douban.com/subject/36464124/buylinks">
#         纸质版 66.00元
#       </a>
#     </span>
#
#           </div>
#
#
#
#
#
#       </div>
#
#     </div>
#   </li>
#
#
#
#
#
# <li class="subject-item">
#     <div class="pic">
#       <a class="nbg" href="https://book.douban.com/subject/27172839/" onclick="moreurl(this,{i:'18',query:'',subject_id:'27172839',from:'book_subject_search'})">
#         <img class="" src="https://img9.doubanio.com/view/subject/s/public/s29580784.jpg" width="90"/>
#       </a>
#     </div>
#     <div class="info">
#       <h2 class="">
#
#
#   <a href="https://book.douban.com/subject/27172839/" title="苏菲的世界" onclick="moreurl(this,{i:'18',query:'',subject_id:'27172839',from:'book_subject_search'})">
#
#     苏菲的世界
#
#
#
#
#   </a>
#
#       </h2>
#       <div class="pub">
#
#
#   [挪威] 乔斯坦·贾德 / 萧宝森 / 作家出版社 / 2017-8 / 38.00元
#
#       </div>
#
#
#
#
#
#
#   <div class="star clearfix">
#         <span class="allstar45"/>
#         <span class="rating_nums">9.1</span>
#
#     <span class="pl">
#         (10603人评价)
#     </span>
#   </div>
#
#
#
#
#
#
#
#     <p>《苏菲的世界》
# 这是一本风靡世界的哲学启蒙书。
# 14岁的少女苏菲不断接到一些极不寻常的来信，世界像谜团一般在她眼底展开，她在一位神秘导师的指引下，苏菲开始思... </p>
#
#
#
#
#
#
#       <div class="ft">
#
#   <div class="collect-info">
#   </div>
#
#
#           <div class="cart-actions">
#
#
#
#
#     <span class="buy-info">
#       <a href="https://book.douban.com/subject/27172839/buylinks">
#         纸质版 28.80元
#       </a>
#     </span>
#
#           </div>
#
#
#
#
#
#       </div>
#
#     </div>
#   </li>
#
#
#
#
#
# <li class="subject-item">
#     <div class="pic">
#       <a class="nbg" href="https://book.douban.com/subject/36488275/" onclick="moreurl(this,{i:'19',query:'',subject_id:'36488275',from:'book_subject_search'})">
#         <img class="" src="https://img2.doubanio.com/view/subject/s/public/s34637581.jpg" width="90"/>
#       </a>
#     </div>
#     <div class="info">
#       <h2 class="">
#
#
#   <a href="https://book.douban.com/subject/36488275/" title="分析哲学的故事" onclick="moreurl(this,{i:'19',query:'',subject_id:'36488275',from:'book_subject_search'})">
#
#     分析哲学的故事
#
#
#
#
#   </a>
#
#       </h2>
#       <div class="pub">
#
#
#   (以) 阿纳特·比莱茨基、(以) 阿纳特·马塔尔 / 刘小涛、何朝安 / 广西师范大学出版社 / 2023-9-1 / 88.00
#
#       </div>
#
#
#
#
#
#
#   <div class="star clearfix">
#
#     <span class="pl">
#         (少于10人评价)
#     </span>
#   </div>
#
#
#
#
#
#
#
#     <p>分析哲学是什么？分析哲学是否已经终结？分析哲学将向何处去？本书正是英美分析哲学界15位知名学者对以上问题的共同回答。本书作者既包括像希拉里·普特南、雅克·亨... </p>
#
#
#
#
#
#
#       <div class="ft">
#
#   <div class="collect-info">
#   </div>
#
#
#           <div class="cart-actions">
#
#
#
#
#     <span class="buy-info">
#       <a href="https://book.douban.com/subject/36488275/buylinks">
#         纸质版 68.60元
#       </a>
#     </span>
#
#           </div>
#
#
#
#
#
#       </div>
#
#     </div>
#   </li>

# %% [markdown]
# **```三种解析情况```**：
# 1. **<u>```根据定位标签，直接解析获得```</u>**，例如用book('.info h2 a').text()获得“人类简史 : 从动物到上帝”
# 2. 用第一种方法获得数据，再进行**<u>```list元素提取```</u>**，例如获得['尤瓦尔·赫拉利 ', ' 林俊宏 ', ' 中信出版社 ', ' 2014-11 ', ' 68.00元']，分别提取作者、出版社、出版时间、价格等4个字段
# 3. 用第一种方法获得数据，再用**<u>```正则表达式提取```</u>**，例如获得“(158378人评价)”，提取“158378（数字）”作为“评价人数（字段）”

# %% [markdown]
# <center><font size=4><b>情况1：直接解析</b></font></center>

# %%
for book in doc.items('.subject-item'):
#     print(book('.info'))     # 一层层定位，找到最具体的标签定位
#     print(book('.info h2'))
#     print(book('.info h2 a'))
#     print(book('.info h2 a').attr('title'))   #取书名的两种方式：一是通过attr方法
#     print(book('.info h2 a').text())          # 二是通过text方法，相对完整
    book_name = book('.info h2 a').text()     # 放入book_name字段中
    print(book_name)
# Out:
# 苏格拉底 : 我们的同时代人
# 悉达多 : 一首印度的诗
# 将熟悉变为陌生 : 与齐格蒙特·鲍曼对谈
# 西方哲学史（第9版）
# 真实与虚拟 : 后真相时代的哲学
# 刘擎西方现代思想讲义
# 哲学之旅 : 一种互动性探究
# 存在主义咖啡馆 : 自由、存在和杏子鸡尾酒
# 被讨厌的勇气
# 大问题 : 简明哲学导论
# 理想国
# 思想之诗 : 从希腊主义到策兰
# 在绝望之巅
# 供词与放逐
# 苦论
# 做哲学 : 88个思想实验中的哲学导论
# 倦怠社会
# 第三次观念飞跃 : 世界冲突的根源与解决之道
# 苏菲的世界
# 分析哲学的故事

# %%
for book in doc.items('.subject-item'):
    print(book('.info h2 a').text())          # 二是通过text方法，相对完整
# Out:
# 苏格拉底 : 我们的同时代人
# 悉达多 : 一首印度的诗
# 将熟悉变为陌生 : 与齐格蒙特·鲍曼对谈
# 西方哲学史（第9版）
# 真实与虚拟 : 后真相时代的哲学
# 刘擎西方现代思想讲义
# 哲学之旅 : 一种互动性探究
# 存在主义咖啡馆 : 自由、存在和杏子鸡尾酒
# 被讨厌的勇气
# 大问题 : 简明哲学导论
# 理想国
# 思想之诗 : 从希腊主义到策兰
# 在绝望之巅
# 供词与放逐
# 苦论
# 做哲学 : 88个思想实验中的哲学导论
# 倦怠社会
# 第三次观念飞跃 : 世界冲突的根源与解决之道
# 苏菲的世界
# 分析哲学的故事

# %%
# 用类似方法的字段有：book_name, desc, score, img
for book in doc.items('.subject-item'):
    book_name = book('.info h2 a').text()
    desc = book('.info p').text()
    score = book('.rating_nums').text()
    img = book('.pic a img').attr('src')
    print(book_name, desc, score, img)
# Out:
# 苏格拉底 : 我们的同时代人 著名历史学家保罗·约翰逊经典作品，冲破柏拉图与色诺芬的围城，还原历史上真实的苏格拉底，描绘我们这一代人的苏格拉底、每个人心中的苏格拉底。大学问出品 · 一部... 9.0 https://img9.doubanio.com/view/subject/s/public/s34628355.jpg
# 悉达多 : 一首印度的诗 《悉达多》并非是佛陀的故事，它讲述了一个人的一生，千万寻常人亦会经历的一生。 意气风发的少年郎，常认为自己是被命运选中的人。抛下过去，随了跌跌撞撞的步伐，找... 9.3 https://img1.doubanio.com/view/subject/s/public/s29396368.jpg
# 将熟悉变为陌生 : 与齐格蒙特·鲍曼对谈 “原来的做事方式全部失效，新的方式却没有被发明出来。这就是我们今天的处境。” * ◎ 《工作、消费主义和新穷人》作者，鲍曼在世最后访谈。 ◎ 当代极具影响力... 8.9 https://img2.doubanio.com/view/subject/s/public/s34593512.jpg
# 西方哲学史（第9版） 畅销五十余载而不衰，备受好评的西哲史教材全新再版 通俗易懂的历史梳理，从古典文籍到当代前沿一应俱全 ◎ 编辑推荐 ☆自1966年初版至今最新修订版 ☆西方哲... 9.2 https://img1.doubanio.com/view/subject/s/public/s33438650.jpg
# 真实与虚拟 : 后真相时代的哲学 这是一个后真相时代，我们对于何为真实的判断暧昧晦暗。现代社会庞大的信息数据网络，除了如同迷魂阵令人难辨真假，也如同牢笼将我们封锁其中。回顾来路，20世纪的变... 9.0 https://img9.doubanio.com/view/subject/s/public/s34579844.jpg
# 刘擎西方现代思想讲义 人生的意义，人们向往的自由和公平的价值，人类文明的复杂冲突与未来趋势……这些让你困惑的大小问题，过去也困扰过韦伯、尼采、萨特等杰出的头脑。他们尽最大努力做出... 9.2 https://img2.doubanio.com/view/subject/s/public/s33802981.jpg
# 哲学之旅 : 一种互动性探究 《哲学之旅：一种互动性探究》是哲学史家威廉·F. 劳海德的代表作，面世后反响极佳，目前已出到第7版。本书是一部富有趣味性、互动性，对读者，尤其是初学者非常友... 8.4 https://img2.doubanio.com/view/subject/s/public/s34675022.jpg
# 存在主义咖啡馆 : 自由、存在和杏子鸡尾酒 巴黎，1933年…… 三位朋友正坐在蒙帕纳斯大道上的煤气灯酒吧里喝着杏子鸡尾酒。其中一个叫雷蒙·阿隆的年轻哲学家，正在向同为哲学家的让-保罗·萨特和西蒙娜·... 8.6 https://img2.doubanio.com/view/subject/s/public/s29675043.jpg
# 被讨厌的勇气 本书用“青年与哲人的对话”这一故事形式总结了与弗洛伊德、荣格并称为“心理学三大巨头”的阿尔弗雷德·阿德勒的思想(阿德勒心理学)。 风靡欧美的阿德勒心理学对于... 8.3 https://img9.doubanio.com/view/subject/s/public/s34348664.jpg
# 大问题 : 简明哲学导论 本书的目的就是引导读者进入真正思考的大门。罗伯特•所罗门教授尤以擅长授课和写作清晰晓畅著称，他不像一般哲学导论著作那样按照事件发生的顺序罗列哲学史上的一些观... 9.3 https://img1.doubanio.com/view/subject/s/public/s29144990.jpg
# 理想国 《理想国》涉及柏拉图思想体系的各个方面，包括哲学、伦理、教育、文艺、政治等内容，主要是探讨理想国家的问题。 《理想国》一书是柏拉图的一篇重要对话录，对话录里... 8.8 https://img1.doubanio.com/view/subject/s/public/s34157889.jpg
# 思想之诗 : 从希腊主义到策兰 人文主义者斯坦纳的诗与思溯源之旅 细细拆解哲学与文学的无穷缠结 【内容简介】 斯坦纳认为，整个西方哲学史中藏着一条文学的暗线，所有思想论说都蕴含风格、形象、... 9.2 https://img1.doubanio.com/view/subject/s/public/s34562738.jpg
# 在绝望之巅 ◎“二十世纪的尼采”、现代欧洲最伟大的哲学家之一 ◎E.M.齐奥朗初试啼声之作 中文简体版首次译介 ★ 在绝望之巅挣扎，燃起超脱生死的激情 将眼泪变成思想，... 8.3 https://img1.doubanio.com/view/subject/s/public/s34219967.jpg
# 供词与放逐 【编辑推荐】 ⭐ “丧”系哲学家·重度失眠病人·最著名的怀疑论者——齐奥朗 他是哲学家E.M.齐奥朗，反叛是他的代名词， 他与伊利亚德、尤内斯库并称“罗马尼... 8.3 https://img9.doubanio.com/view/subject/s/public/s34595866.jpg
# 苦论 【编辑推荐】 ⭐危险哲学家齐奥朗，人生首部短句集！在法国最畅销、最受欢迎之作 “与齐奥朗交朋友是有危险的，但这种危险能让你活着。” 危险哲学家齐奥朗，用“碎... 7.9 https://img1.doubanio.com/view/subject/s/public/s34595870.jpg
# 做哲学 : 88个思想实验中的哲学导论 你从未读到过的哲学导论 磨砺审辩性思维技巧的方法指南 于哲学实践中锤炼理论想象力和逻辑分析能力 用思想实验不停挑战并重塑你对世界的认知和判断 …………………... 9.3 https://img2.doubanio.com/view/subject/s/public/s33823033.jpg
# 倦怠社会 否定性的社会已经消失，取而代之的是充溢着积极性的社会。 从这一范式转移出发，韩炳哲展示了当今社会的病理形态，其中包括忧郁症、注意力缺乏症、过劳症等精神疾病。... 7.8 https://img2.doubanio.com/view/subject/s/public/s33300502.jpg
# 第三次观念飞跃 : 世界冲突的根源与解决之道 环境保护、胎儿权利、婚姻定义、身份认同、移民问题、言论边界…… “世界”与“自我”无法兼容的时代，我们如何自处？ 探寻政治与道德分歧的深层根源，一场针对主体... 8.5 https://img1.doubanio.com/view/subject/s/public/s34637350.jpg
# 苏菲的世界 《苏菲的世界》 这是一本风靡世界的哲学启蒙书。 14岁的少女苏菲不断接到一些极不寻常的来信，世界像谜团一般在她眼底展开，她在一位神秘导师的指引下，苏菲开始思... 9.1 https://img9.doubanio.com/view/subject/s/public/s29580784.jpg
# 分析哲学的故事 分析哲学是什么？分析哲学是否已经终结？分析哲学将向何处去？本书正是英美分析哲学界15位知名学者对以上问题的共同回答。本书作者既包括像希拉里·普特南、雅克·亨...  https://img2.doubanio.com/view/subject/s/public/s34637581.jpg

# %% [markdown]
# <center><font size=4><b>情况2：提取列表元素</b></font></center>

# %%
for book in doc.items('.subject-item'):
#     info_list = book('.info .pub').text()    # 用左下划线'/'分隔的字符串
    info_list = book('.info .pub').text().split('/')     # 以'/'为分隔符split，得到info_list列表
#     print(info_list)
#     print(info_list[-3])    # 用[]提取列表元素，例如倒数第3个是出版社，索引为-3
    publisher = info_list[-3].strip()   # 以同样的方式获得authors, publisher, pub_time, price字段
#     print(publisher)
    pub_time = info_list[-2]
    price = info_list[-1]
    authors = ','.join(info_list[:-3])   # 将多个作者元素，组合到一个字符串里
#     print(authors)
    print(authors, publisher, pub_time, price)
# Out:
# [英] 保罗·约翰逊 , 郝苑  广西师范大学出版社  2023-9   58
# [德] 赫尔曼·黑塞 , 姜乙  天津人民出版社  2017-1   32.00元
# [英] 齐格蒙·鲍曼、[瑞士] 彼得·哈夫纳 , 王立秋  南京大学出版社  2023-8-6   68.00元
# (美) 撒穆尔·伊诺克·斯通普夫、(美) 詹姆斯·菲泽 , 邓晓芒、匡宏、等  北京联合出版公司  2019-8   99.80元
# 金观涛  中信出版社  2023-7   98元
# 刘擎  新星出版社  2021-1   79.00元
# (美) 威廉·F. 劳海德 , 张祖辽、杨东东  东方出版中心  2023-9   160.00元
# [英] 莎拉·贝克韦尔 , 沈敏一  北京联合出版公司  2017-12-1   88.00
# (日) 岸见一郎，古贺史健 , 渠海霞  机械工业出版社  2021-1   55
# [美] 罗伯特·所罗门、凯思林•希金斯 , 张卜天  广西师范大学出版社  2014-12   65.00
# [古希腊] 柏拉图 , 郭斌和、张竹明  商务印书馆  1986-8   28.00元
# [美]乔治·斯坦纳 , 远子  广西师范大学出版社  2023-8   79.00元
# [法国] E·M·齐奥朗 , 唐江  北京联合出版公司  2022-6   49.80
# [法]E.M.齐奥朗 , 赵苓岑  广西师范大学出版社  2023-8   39.8元
# [法国] E.M.齐奥朗 , 蔡羽婷  广西师范大学出版社  2023-8   39.8元
# [美] 小西奥多·希克、刘易斯·沃恩 , 柴伟佳、龚皓  北京联合出版公司  2018-8   118.00元
# [德] 韩炳哲 , 王一力  中信出版集团  2019-6-1   35.00元
# [美]琳达·扎格泽博斯基 , 孙天  广西师范大学出版社  2023-10   88.00元
# [挪威] 乔斯坦·贾德 , 萧宝森  作家出版社  2017-8   38.00元
# (以) 阿纳特·比莱茨基、(以) 阿纳特·马塔尔 , 刘小涛、何朝安  广西师范大学出版社  2023-9-1   88.00

# %% [markdown]
# <center><font size=4><b>情况3：正则表达式提取</b></font></center>

# %%
import re    # 导入re包

for book in doc.items('.subject-item'):
    people_num_raw = book('.pl').text()
#     print(people_num_raw)
#     print(re.findall('[0-9]+', people_num_raw))    # 匹配people_num_raw字段中的数字，获得列表
#     print(re.findall('[0-9]+', people_num_raw)[0])   # 取列表中的第1个元素，索引为0
    people_num = re.findall('[0-9]+', people_num_raw)[0]  # 放入people_num字段中
    print(people_num)
# Out:
# 71
# 86461
# 1289
# 2905
# 156
# 33298
# 21
# 15914
# 16557
# 8168
# 35944
# 89
# 6514
# 302
# 428
# 812
# 12272
# 51
# 10603
# 10

# %% [markdown]
# 1. 将这些**```字段组合成字典，放入列表```**中
# 2. 书名、作者、出版社等作为**```key```**，人类简史、尤瓦尔·赫拉利、中信出版社等作为**```value```**
# 3. **```例子```**如下：

# %%
bookinfo_list_tmp = [
    {'book_name': '人类简史：从动物到上帝', 'author': '尤瓦尔·赫拉利', 'publisher': '中信出版社'},
    {'book_name': '理想国', 'author': '柏拉图', 'publisher': '商务印书馆'},
    {'book_name': '社会契约论', 'author': '卢梭', 'publisher': '商务印书馆'}
    ]
print(bookinfo_list_tmp)
print('数据类型为：',type(bookinfo_list_tmp))   # 类型为list
print('数据长度为：',len(bookinfo_list_tmp))    # 长度为3，即3本书的信息
# Out:
# [{'book_name': '人类简史：从动物到上帝', 'author': '尤瓦尔·赫拉利', 'publisher': '中信出版社'}, {'book_name': '理想国', 'author': '柏拉图', 'publisher': '商务印书馆'}, {'book_name': '社会契约论', 'author': '卢梭', 'publisher': '商务印书馆'}]
# 数据类型为： <class 'list'>
# 数据长度为： 3

# %%
bookinfo_list = []   # 生成空列表，用于存储书籍信息
doc = PyQuery(html)
for book in doc.items('.subject-item'):
    book_name = book('.info h2 a').text()    # 情况1：直接解析
    desc = book('.info p').text()
    score = book('.rating_nums').text()
    img = book('.pic a img').attr('src')
    
    info_list = book('.info .pub').text().split('/')    # 情况2：提取列表元素
    publisher = info_list[-3].strip()   
    pub_time = info_list[-2]
    price = info_list[-1]
    authors = ''.join(info_list[:-3]) 
    
    people_num_raw = book('.pl').text()       # 情况3：正则表达式提取
    people_num = re.findall('[0-9]+', people_num_raw)[0]
    
    bookinfo = {'book_name':book_name,   # 为每本书创建一个字典，不同字段建构不同键值对
                 'authors':authors,
                 'publisher':publisher,
                 'pub_time':pub_time,
                 'desc':desc,
                 'score':score,
                 'people_num':people_num,
                 'price':price,
                 'img':img
                }
    
    bookinfo_list.append(bookinfo)      # 将字典添加进bookinfo_list列表中

# %%
bookinfo_list
# len(bookinfo_list)
# Out:
# [{'book_name': '苏格拉底 : 我们的同时代人',
#   'authors': '[英] 保罗·约翰逊  郝苑 ',
#   'publisher': '广西师范大学出版社',
#   'pub_time': ' 2023-9 ',
#   'desc': '著名历史学家保罗·约翰逊经典作品，冲破柏拉图与色诺芬的围城，还原历史上真实的苏格拉底，描绘我们这一代人的苏格拉底、每个人心中的苏格拉底。大学问出品 · 一部...',
#   'score': '9.0',
#   'people_num': '71',
#   'price': ' 58',
#   'img': 'https://img9.doubanio.com/view/subject/s/public/s34628355.jpg'},
#  {'book_name': '悉达多 : 一首印度的诗',
#   'authors': '[德] 赫尔曼·黑塞  姜乙 ',
#   'publisher': '天津人民出版社',
#   'pub_time': ' 2017-1 ',
#   'desc': '《悉达多》并非是佛陀的故事，它讲述了一个人的一生，千万寻常人亦会经历的一生。 意气风发的少年郎，常认为自己是被命运选中的人。抛下过去，随了跌跌撞撞的步伐，找...',
#   'score': '9.3',
#   'people_num': '86461',
#   'price': ' 32.00元',
#   'img': 'https://img1.doubanio.com/view/subject/s/public/s29396368.jpg'},
#  {'book_name': '将熟悉变为陌生 : 与齐格蒙特·鲍曼对谈',
#   'authors': '[英] 齐格蒙·鲍曼、[瑞士] 彼得·哈夫纳  王立秋 ',
#   'publisher': '南京大学出版社',
#   'pub_time': ' 2023-8-6 ',
#   'desc': '“原来的做事方式全部失效，新的方式却没有被发明出来。这就是我们今天的处境。” * ◎ 《工作、消费主义和新穷人》作者，鲍曼在世最后访谈。 ◎ 当代极具影响力...',
#   'score': '8.9',
#   'people_num': '1289',
#   'price': ' 68.00元',
#   'img': 'https://img2.doubanio.com/view/subject/s/public/s34593512.jpg'},
#  {'book_name': '西方哲学史（第9版）',
#   'authors': '(美) 撒穆尔·伊诺克·斯通普夫、(美) 詹姆斯·菲泽  邓晓芒、匡宏、等 ',
#   'publisher': '北京联合出版公司',
#   'pub_time': ' 2019-8 ',
#   'desc': '畅销五十余载而不衰，备受好评的西哲史教材全新再版 通俗易懂的历史梳理，从古典文籍到当代前沿一应俱全 ◎ 编辑推荐 ☆自1966年初版至今最新修订版 ☆西方哲...',
#   'score': '9.2',
#   'people_num': '2905',
#   'price': ' 99.80元',
#   'img': 'https://img1.doubanio.com/view/subject/s/public/s33438650.jpg'},
#  {'book_name': '真实与虚拟 : 后真相时代的哲学',
#   'authors': '金观涛 ',
#   'publisher': '中信出版社',
#   'pub_time': ' 2023-7 ',
#   'desc': '这是一个后真相时代，我们对于何为真实的判断暧昧晦暗。现代社会庞大的信息数据网络，除了如同迷魂阵令人难辨真假，也如同牢笼将我们封锁其中。回顾来路，20世纪的变...',
#   'score': '9.0',
#   'people_num': '156',
#   'price': ' 98元',
#   'img': 'https://img9.doubanio.com/view/subject/s/public/s34579844.jpg'},
#  {'book_name': '刘擎西方现代思想讲义',
#   'authors': '刘擎 ',
#   'publisher': '新星出版社',
#   'pub_time': ' 2021-1 ',
#   'desc': '人生的意义，人们向往的自由和公平的价值，人类文明的复杂冲突与未来趋势……这些让你困惑的大小问题，过去也困扰过韦伯、尼采、萨特等杰出的头脑。他们尽最大努力做出...',
#   'score': '9.2',
#   'people_num': '33298',
#   'price': ' 79.00元',
#   'img': 'https://img2.doubanio.com/view/subject/s/public/s33802981.jpg'},
#  {'book_name': '哲学之旅 : 一种互动性探究',
#   'authors': '(美) 威廉·F. 劳海德  张祖辽、杨东东 ',
#   'publisher': '东方出版中心',
#   'pub_time': ' 2023-9 ',
#   'desc': '《哲学之旅：一种互动性探究》是哲学史家威廉·F. 劳海德的代表作，面世后反响极佳，目前已出到第7版。本书是一部富有趣味性、互动性，对读者，尤其是初学者非常友...',
#   'score': '8.4',
#   'people_num': '21',
#   'price': ' 160.00元',
#   'img': 'https://img2.doubanio.com/view/subject/s/public/s34675022.jpg'},
#  {'book_name': '存在主义咖啡馆 : 自由、存在和杏子鸡尾酒',
#   'authors': '[英] 莎拉·贝克韦尔  沈敏一 ',
#   'publisher': '北京联合出版公司',
#   'pub_time': ' 2017-12-1 ',
#   'desc': '巴黎，1933年…… 三位朋友正坐在蒙帕纳斯大道上的煤气灯酒吧里喝着杏子鸡尾酒。其中一个叫雷蒙·阿隆的年轻哲学家，正在向同为哲学家的让-保罗·萨特和西蒙娜·...',
#   'score': '8.6',
#   'people_num': '15914',
#   'price': ' 88.00',
#   'img': 'https://img2.doubanio.com/view/subject/s/public/s29675043.jpg'},
#  {'book_name': '被讨厌的勇气',
#   'authors': '(日) 岸见一郎，古贺史健  渠海霞 ',
#   'publisher': '机械工业出版社',
#   'pub_time': ' 2021-1 ',
#   'desc': '本书用“青年与哲人的对话”这一故事形式总结了与弗洛伊德、荣格并称为“心理学三大巨头”的阿尔弗雷德·阿德勒的思想(阿德勒心理学)。 风靡欧美的阿德勒心理学对于...',
#   'score': '8.3',
#   'people_num': '16557',
#   'price': ' 55',
#   'img': 'https://img9.doubanio.com/view/subject/s/public/s34348664.jpg'},
#  {'book_name': '大问题 : 简明哲学导论',
#   'authors': '[美] 罗伯特·所罗门、凯思林•希金斯  张卜天 ',
#   'publisher': '广西师范大学出版社',
#   'pub_time': ' 2014-12 ',
#   'desc': '本书的目的就是引导读者进入真正思考的大门。罗伯特•所罗门教授尤以擅长授课和写作清晰晓畅著称，他不像一般哲学导论著作那样按照事件发生的顺序罗列哲学史上的一些观...',
#   'score': '9.3',
#   'people_num': '8168',
#   'price': ' 65.00',
#   'img': 'https://img1.doubanio.com/view/subject/s/public/s29144990.jpg'},
#  {'book_name': '理想国',
#   'authors': '[古希腊] 柏拉图  郭斌和、张竹明 ',
#   'publisher': '商务印书馆',
#   'pub_time': ' 1986-8 ',
#   'desc': '《理想国》涉及柏拉图思想体系的各个方面，包括哲学、伦理、教育、文艺、政治等内容，主要是探讨理想国家的问题。 《理想国》一书是柏拉图的一篇重要对话录，对话录里...',
#   'score': '8.8',
#   'people_num': '35944',
#   'price': ' 28.00元',
#   'img': 'https://img1.doubanio.com/view/subject/s/public/s34157889.jpg'},
#  {'book_name': '思想之诗 : 从希腊主义到策兰',
#   'authors': '[美]乔治·斯坦纳  远子 ',
#   'publisher': '广西师范大学出版社',
#   'pub_time': ' 2023-8 ',
#   'desc': '人文主义者斯坦纳的诗与思溯源之旅 细细拆解哲学与文学的无穷缠结 【内容简介】 斯坦纳认为，整个西方哲学史中藏着一条文学的暗线，所有思想论说都蕴含风格、形象、...',
#   'score': '9.2',
#   'people_num': '89',
#   'price': ' 79.00元',
#   'img': 'https://img1.doubanio.com/view/subject/s/public/s34562738.jpg'},
#  {'book_name': '在绝望之巅',
#   'authors': '[法国] E·M·齐奥朗  唐江 ',
#   'publisher': '北京联合出版公司',
#   'pub_time': ' 2022-6 ',
#   'desc': '◎“二十世纪的尼采”、现代欧洲最伟大的哲学家之一 ◎E.M.齐奥朗初试啼声之作 中文简体版首次译介 ★ 在绝望之巅挣扎，燃起超脱生死的激情 将眼泪变成思想，...',
#   'score': '8.3',
#   'people_num': '6514',
#   'price': ' 49.80',
#   'img': 'https://img1.doubanio.com/view/subject/s/public/s34219967.jpg'},
#  {'book_name': '供词与放逐',
#   'authors': '[法]E.M.齐奥朗  赵苓岑 ',
#   'publisher': '广西师范大学出版社',
#   'pub_time': ' 2023-8 ',
#   'desc': '【编辑推荐】 ⭐ “丧”系哲学家·重度失眠病人·最著名的怀疑论者——齐奥朗 他是哲学家E.M.齐奥朗，反叛是他的代名词， 他与伊利亚德、尤内斯库并称“罗马尼...',
#   'score': '8.3',
#   'people_num': '302',
#   'price': ' 39.8元',
#   'img': 'https://img9.doubanio.com/view/subject/s/public/s34595866.jpg'},
#  {'book_name': '苦论',
#   'authors': '[法国] E.M.齐奥朗  蔡羽婷 ',
#   'publisher': '广西师范大学出版社',
#   'pub_time': ' 2023-8 ',
#   'desc': '【编辑推荐】 ⭐危险哲学家齐奥朗，人生首部短句集！在法国最畅销、最受欢迎之作 “与齐奥朗交朋友是有危险的，但这种危险能让你活着。” 危险哲学家齐奥朗，用“碎...',
#   'score': '7.9',
#   'people_num': '428',
#   'price': ' 39.8元',
#   'img': 'https://img1.doubanio.com/view/subject/s/public/s34595870.jpg'},
#  {'book_name': '做哲学 : 88个思想实验中的哲学导论',
#   'authors': '[美] 小西奥多·希克、刘易斯·沃恩  柴伟佳、龚皓 ',
#   'publisher': '北京联合出版公司',
#   'pub_time': ' 2018-8 ',
#   'desc': '你从未读到过的哲学导论 磨砺审辩性思维技巧的方法指南 于哲学实践中锤炼理论想象力和逻辑分析能力 用思想实验不停挑战并重塑你对世界的认知和判断 …………………...',
#   'score': '9.3',
#   'people_num': '812',
#   'price': ' 118.00元',
#   'img': 'https://img2.doubanio.com/view/subject/s/public/s33823033.jpg'},
#  {'book_name': '倦怠社会',
#   'authors': '[德] 韩炳哲  王一力 ',
#   'publisher': '中信出版集团',
#   'pub_time': ' 2019-6-1 ',
#   'desc': '否定性的社会已经消失，取而代之的是充溢着积极性的社会。 从这一范式转移出发，韩炳哲展示了当今社会的病理形态，其中包括忧郁症、注意力缺乏症、过劳症等精神疾病。...',
#   'score': '7.8',
#   'people_num': '12272',
#   'price': ' 35.00元',
#   'img': 'https://img2.doubanio.com/view/subject/s/public/s33300502.jpg'},
#  {'book_name': '第三次观念飞跃 : 世界冲突的根源与解决之道',
#   'authors': '[美]琳达·扎格泽博斯基  孙天 ',
#   'publisher': '广西师范大学出版社',
#   'pub_time': ' 2023-10 ',
#   'desc': '环境保护、胎儿权利、婚姻定义、身份认同、移民问题、言论边界…… “世界”与“自我”无法兼容的时代，我们如何自处？ 探寻政治与道德分歧的深层根源，一场针对主体...',
#   'score': '8.5',
#   'people_num': '51',
#   'price': ' 88.00元',
#   'img': 'https://img1.doubanio.com/view/subject/s/public/s34637350.jpg'},
#  {'book_name': '苏菲的世界',
#   'authors': '[挪威] 乔斯坦·贾德  萧宝森 ',
#   'publisher': '作家出版社',
#   'pub_time': ' 2017-8 ',
#   'desc': '《苏菲的世界》 这是一本风靡世界的哲学启蒙书。 14岁的少女苏菲不断接到一些极不寻常的来信，世界像谜团一般在她眼底展开，她在一位神秘导师的指引下，苏菲开始思...',
#   'score': '9.1',
#   'people_num': '10603',
#   'price': ' 38.00元',
#   'img': 'https://img9.doubanio.com/view/subject/s/public/s29580784.jpg'},
#  {'book_name': '分析哲学的故事',
#   'authors': '(以) 阿纳特·比莱茨基、(以) 阿纳特·马塔尔  刘小涛、何朝安 ',
#   'publisher': '广西师范大学出版社',
#   'pub_time': ' 2023-9-1 ',
#   'desc': '分析哲学是什么？分析哲学是否已经终结？分析哲学将向何处去？本书正是英美分析哲学界15位知名学者对以上问题的共同回答。本书作者既包括像希拉里·普特南、雅克·亨...',
#   'score': '',
#   'people_num': '10',
#   'price': ' 88.00',
#   'img': 'https://img2.doubanio.com/view/subject/s/public/s34637581.jpg'}]

# %%
# 函数：解析数据  extract_bookinfo_list(html)
# 参数说明：html为网页源代码的字符串
# 返回值：bookinfo_list为书籍的字典列表
def extract_bookinfo_list(html):         # 添加：定义函数名
    bookinfo_list = []
    doc = PyQuery(html)
    for book in doc.items('.subject-item'):
        try:                             # 添加：try语句，避免特殊网页中断整个循环
            book_name = book('.info h2 a').text()    
            desc = book('.info p').text()
            score = book('.rating_nums').text()
            img = book('.pic a img').attr('src')
            info_list = book('.info .pub').text().split('/')    
            publisher = info_list[-3].strip()   
            pub_time = info_list[-2]
            price = info_list[-1]
            authors = ''.join(info_list[:-3])
            people_num_raw = book('.pl').text()       
            people_num = re.findall('[0-9]+', people_num_raw)[0]

            bookinfo = {'book_name':book_name,
                         'authors':authors,
                         'publisher':publisher,
                         'pub_time':pub_time,
                         'desc':desc,
                         'score':score,
                         'people_num':people_num,
                         'price':price,
                         'img':img
                        }

            bookinfo_list.append(bookinfo)
        except:                        # 添加：except和pass语句，如果碰到bug，那么跳出此次循环、不执行任何操作，进行下一次循环
            pass
        
    return bookinfo_list               # 添加：返回书籍的字典列表

# %%
html
# Out:
# '\n\n<!DOCTYPE html>\n<html lang="zh-cmn-Hans" class="ua-windows ua-webkit book-new-nav">\n<head>\n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n  <title>\n  豆瓣图书标签: 哲学\n</title>\n  \n<script>!function(e){var o=function(o,n,t){var c,i,r=new Date;n=n||30,t=t||"/",r.setTime(r.getTime()+24*n*60*60*1e3),c="; expires="+r.toGMTString();for(i in o)e.cookie=i+"="+o[i]+c+"; path="+t},n=function(o){var n,t,c,i=o+"=",r=e.cookie.split(";");for(t=0,c=r.length;t<c;t++)if(n=r[t].replace(/^\\s+|\\s+$/g,""),0==n.indexOf(i))return n.substring(i.length,n.length).replace(/\\"/g,"");return null},t=e.write,c={"douban.com":1,"douban.fm":1,"google.com":1,"google.cn":1,"googleapis.com":1,"gmaptiles.co.kr":1,"gstatic.com":1,"gstatic.cn":1,"google-analytics.com":1,"googleadservices.com":1},i=function(e,o){var n=new Image;n.onload=function(){},n.src="https://www.douban.com/j/except_report?kind=ra022&reason="+encodeURIComponent(e)+"&environment="+encodeURIComponent(o)},r=function(o){try{t.call(e,o)}catch(e){t(o)}},a=/<script.*?src\\=["\']?([^"\'\\s>]+)/gi,g=/http:\\/\\/(.+?)\\.([^\\/]+).+/i;e.writeln=e.write=function(e){var t,l=a.exec(e);return l&&(t=g.exec(l[1]))?c[t[2]]?void r(e):void("tqs"!==n("hj")&&(i(l[1],location.href),o({hj:"tqs"},1),setTimeout(function(){location.replace(location.href)},50))):void r(e)}}(document);</script>\n\n  \n  <meta http-equiv="Pragma" content="no-cache">\n  <meta http-equiv="Expires" content="Sun, 6 Mar 2005 01:00:00 GMT">\n  \n  <script>var _head_start = new Date();</script>\n  \n  <link href="https://img1.doubanio.com/f/book/8011541306494bc2ff483299d952d9c65753c43d/css/book/master.css" rel="stylesheet" type="text/css">\n\n  <link href="https://img1.doubanio.com/f/book/222a5c61e041638af8defc87cf97f4a863a77922/css/book/base/init.css" rel="stylesheet">\n  <style type="text/css"></style>\n  <script src="https://img1.doubanio.com/f/book/0495cb173e298c28593766009c7b0a953246c5b5/js/book/lib/jquery/jquery.js"></script>\n  <script src="https://img1.doubanio.com/f/shire/4888ee2fda6812f70a064a51c93b84fde8e4a3c2/js/douban.js"></script>\n  <script src="https://img1.doubanio.com/f/book/0322e3e810e475f1c82adb7d1c6ccfa1c0fa969c/js/book/master.js"></script>\n  \n\n  \n  <script>  </script>\n  <link rel="stylesheet" href="https://img1.doubanio.com/misc/mixed_static/468bc24284a3074.css">\n\n  <link rel="shortcut icon" href="https://img1.doubanio.com/favicon.ico" type="image/x-icon">\n</head>\n<body>\n  \n    <script>var _body_start = new Date();</script>\n    \n  \n\n\n\n    <link href="//img3.doubanio.com/dae/accounts/resources/164cfd8/shire/bundle.css" rel="stylesheet" type="text/css">\n\n\n\n<div id="db-global-nav" class="global-nav">\n  <div class="bd">\n    \n<div class="top-nav-info">\n  <a href="https://accounts.douban.com/passport/login?source=book" class="nav-login" rel="nofollow">登录/注册</a>\n</div>\n\n\n    <div class="top-nav-doubanapp">\n  <a href="https://www.douban.com/doubanapp/app?channel=top-nav" class="lnk-doubanapp">下载豆瓣客户端</a>\n  <div id="doubanapp-tip">\n    <a href="https://www.douban.com/doubanapp/app?channel=qipao" class="tip-link">豆瓣 <span class="version">6.0</span> 全新发布</a>\n    <a href="javascript: void 0;" class="tip-close">×</a>\n  </div>\n  <div id="top-nav-appintro" class="more-items">\n    <p class="appintro-title">豆瓣</p>\n    <p class="qrcode">扫码直接下载</p>\n    <div class="download">\n      <a href="https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=iOS">iPhone</a>\n      <span>·</span>\n      <a href="https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=Android" class="download-android">Android</a>\n    </div>\n  </div>\n</div>\n\n    \n\n\n<div class="global-nav-items">\n  <ul>\n    <li class="">\n      <a href="https://www.douban.com" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-main&quot;,&quot;uid&quot;:&quot;0&quot;}">豆瓣</a>\n    </li>\n    <li class="on">\n      <a href="https://book.douban.com"  d ...

# %%
# 调用函数extract_bookinfo_list(html)
bookinfo_list = extract_bookinfo_list(html)
print(bookinfo_list)
print('书籍数量为：', len(bookinfo_list))
# Out:
# [{'book_name': '悉达多 : 一首印度的诗', 'authors': '[德] 赫尔曼·黑塞  姜乙 ', 'publisher': '天津人民出版社', 'pub_time': ' 2017-1 ', 'desc': '《悉达多》并非是佛陀的故事，它讲述了一个人的一生，千万寻常人亦会经历的一生。 意气风发的少年郎，常认为自己是被命运选中的人。抛下过去，随了跌跌撞撞的步伐，找...', 'score': '9.3', 'people_num': '77014', 'price': ' 32.00元', 'img': 'https://img1.doubanio.com/view/subject/s/public/s29396368.jpg'}, {'book_name': '敏感与自我', 'authors': '[德]斯文娅·弗拉斯珀勒  许一诺、包向飞 ', 'publisher': '上海三联书店', 'pub_time': ' 2023-4 ', 'desc': '我们比以往任何时候都更忙于调整合理的限度。可以说的边界在哪里？什么时候触摸变得让人厌恶？本书作者后退一步，揭示了冲突的核心：自我和社会的日益敏感化。 聚焦敏...', 'score': '8.7', 'people_num': '269', 'price': ' 49元', 'img': 'https://img9.doubanio.com/view/subject/s/public/s34506625.jpg'}, {'book_name': '真实与虚拟 : 后真相时代的哲学', 'authors': '金观涛 ', 'publisher': '中信出版社', 'pub_time': ' 2023-7 ', 'desc': '这是一个后真相时代，我们对于何为真实的判断暧昧晦暗。现代社会庞大的信息数据网络，除了如同迷魂阵令人难辨真假，也如同牢笼将我们封锁其中。回顾来路，20世纪的变...', 'score': '8.8', 'people_num': '51', 'price': ' 98元', 'img': 'https://img9.doubanio.com/view/subject/s/public/s34579844.jpg'}, {'book_name': '刘擎西方现代思想讲义', 'authors': '刘擎 ', 'publisher': '新星出版社', 'pub_time': ' 2021-1 ', 'desc': '人生的意义，人们向往的自由和公平的价值，人类文明的复杂冲突与未来趋势……这些让你困惑的大小问题，过去也困扰过韦伯、尼采、萨特等杰出的头脑。他们尽最大努力做出...', 'score': '9.2', 'people_num': '31497', 'price': ' 79.00元', 'img': 'https://img2.doubanio.com/view/subject/s/public/s33802981.jpg'}, {'book_name': '维特根斯坦十讲', 'authors': '楼巍 ', 'publisher': '上海文艺出版社', 'pub_time': ' 2023-5-1 ', 'desc': '一本书让你理解维特根斯坦 浙江大学教授楼巍10堂哲学课 名校教授联合推荐：陈嘉映、江怡、黄敏、刘畅、代海强 裸脊锁线装订、印银、可180度摊开，颜值天花板设...', 'score': '8.9', 'people_num': '53', 'price': ' 68.00', 'img': 'https://img1.doubanio.com/view/subject/s/public/s34516877.jpg'}, {'book_name': '大问题 : 简明哲学导论', 'authors': '[美] 罗伯特·所罗门、凯思林•希金斯  张卜天 ', 'publisher': '广西师范大学出版社', 'pub_time': ' 2014-12 ', 'desc': '本书的目的就是引导读者进入真正思考的大门。罗伯特•所罗门教授尤以擅长授课和写作清晰晓畅著称，他不像一般哲学导论著作那样按照事件发生的顺序罗列哲学史上的一些观...', 'score': '9.3', 'people_num': '8062', 'price': ' 65.00', 'img': 'https://img1.doubanio.com/view/subject/s/public/s29144990.jpg'}, {'book_name': '理想国', 'authors': '[古希腊] 柏拉图  郭斌和、张竹明 ', 'publisher': '商务印书馆', 'pub_time': ' 1986-8 ', 'desc': '《理想国》涉及柏拉图思想体系的各个方面，包括哲学、伦理、教育、文艺、政治等内容，主要是探讨理想国家的问题。 《理想国》一书是柏拉图的一篇重要对话录，对话录里...', 'score': '8.8', 'people_num': '35217', 'price': ' 28.00元', 'img': 'https://img1.doubanio.com/view/subject/s/public/s34157889.jpg'}, {'book_name': '西方哲学史（第9版）', 'authors': '(美) 撒穆尔·伊诺克·斯通普夫、(美) 詹姆斯·菲泽  邓晓芒、匡宏、等 ', 'publisher': '北京联合出版公司', 'pub_time': ' 2019-8 ', 'desc': '畅销五十余载而不衰，备受好评的西哲史教材全新再版 通俗易懂的历史梳理，从古典文籍到当代前沿一应俱全 ◎ 编辑推荐 ☆自1966年初版至今最新修订版 ☆西方哲...', 'score': '9.2', 'people_num': '2718', 'price': ' 99.80元', 'img': 'https://img1.doubanio.com/view/subject/s/public/s33438650.jpg'}, {'book_name': '大问题 : 简明哲学导论', 'authors': '[美] 罗伯特·所罗门、[美] 凯思林·希金斯  张卜天 ', 'publisher': '清华大学出版社', 'pub_time': ' 2018-7 ', 'desc': '本书的目的就是引导读者进入真正思考的大门。罗伯特·所罗门教授尤以擅长授课和写作清晰流畅著称，他不像一般哲学导论著作那样按照事件发生的顺序罗列哲学史上的一些观...', 'score': '9.3', 'people_num': '2645', 'price': ' 98.00元', 'img': 'https://img9.doubanio.com/view/subject/s/public/s33923794.jpg'}, {'book_name': '被讨厌的勇气', 'authors': '(日) 岸见一郎，古贺史健  渠海霞 ', 'publisher': '机械工业出版社', 'pub_time': ' 2021-1 ', 'desc': '本书用“青年与哲人的对话”这一故事形式总结了与弗洛伊德、荣格并称为“心理学三大巨头”的阿尔弗雷德·阿德勒的思想(阿德勒心理学)。 风靡欧美的阿德勒心理学对于...', 'score': '8.4', 'people_num': '11712', 'price': ' 55', 'img': 'https://img9.doubanio.com/view/subject/s/public/s34348664.jpg'}, {'book_name': '现象学入门', 'authors': '[丹麦]丹·扎哈维  康维阳 ', 'publisher': '商务印书馆', 'pub_time': ' 2023-5 ', 'desc': '⭐️目前已经有德文、英文、日文等6译本⭐️ ⭐️本书依据的英文版豆瓣评分9.6分⭐️ 本书是丹·扎哈维对20世纪主导性哲学运动之一的现象学简明而有吸引力的介...', 'score': '9.9', 'people_num': '101', 'price': ' 58.00元', 'img': 'https://img2.doubanio.com/view/subject/s/public/s34507612.jpg'}, {'book_name': '苏菲的世界', 'authors': '[挪威] 乔斯坦·贾德  萧宝森 ', 'publisher': '作家出版社', 'pub_time': ' 2017-8 ', 'desc': '《苏菲的世界》 这是一本风靡世界的哲学启蒙书。 14岁的少女苏菲不断接到一些极不寻常的来信，世界像谜团一般在她眼底展开，她在一位神秘导师的指引下，苏菲开始思...', 'score': '9.0', 'people_num': '10067', 'price': ' 38.00元', 'img': 'https://img9.doubanio.com/view/subject/s/public/s29580784.jpg'}, {'book_name': '哲学的历程 : 西方哲学历史导论(第四版)', 'autho ...
# 书籍数量为： 20

# %% [markdown]
# # 存储数据

# %%
import csv     # 导入csv包

# 打开文件
file = open('./data//books_philosophy.csv', 'a+', encoding='utf-8', newline='') # 文件名为books_philosophy.csv，模式为a+，如果已有文件，在末尾追加，如果没，则生成新文件；编码为utf-8，需要区分换行符
fieldnames = ['book_name', 'authors', 'publisher', 'pub_time', 'desc', 'score', 'people_num', 'price', 'img']  # 设置标题行fieldnames
writer = csv.DictWriter(file, fieldnames=fieldnames)    # 要求以字典的形式写入数据，fieldnames注明字典中键的名称，也就是书名、作者这些标题名
writer.writeheader()  # 将fieldnames设置的标题key写入首行

# 循环写入字典列表：因为有很多本书，需要一行行写入
for bookinfo in bookinfo_list:
    writer.writerow(bookinfo)  # 写入一行书籍信息
    
file.close() # 关闭文件

# %% [markdown]
# # 批量爬取

# %% [markdown]
# 刚才我们做了几项工作：
# 1. 生成网址————发现网址规律，获得所有网址url_list
# 2. 请求+获取网页数据————获得html网页源代码字符串（**单个网址**）
# 3. 解析数据————从html中获得书籍的各字段信息，存储为字典列表（**单个网址**）
# 4. 存储数据（**单个网址**）
# <br>
# <br>
# <br>
# <b><mark>下面对所有网址url_list循环步骤2-4</mark><b>

# %% [markdown]
# |**步骤**|任务|函数|输入参数|返回值|
# |:----:|:-----|:-----|:-----|:-----|
# |1|生成网址|generate_url_list()|--|url_list网址列表|
# |**<mark>2</mark>**|**<mark>请求+获取网页数据</mark>**|get_html(url)|单个网址|html网页源代码的字符串|
# |**<mark>3</mark>**|**<mark>解析数据</mark>**|extract_bookinfo_list(html)|（单个网址）html网页源代码的字符串|bookinfo_list书籍的字典列表|
# |**<mark>4</mark>**|**<mark>存储数据</mark>**|--|--|--|
# |5|批量爬取|--|--|--|

# %% [markdown]
#     为方便讲解，此处爬取5页作为例子（range中数字改为6）

# %%
# 生成5页的网址url_list
url_list = []
template = 'https://book.douban.com/tag/哲学?start={num}&type=T'
for p in range(1,6):   # range取1到5
    url = template.format(num=(p-1)*20)
    url_list.append(url)
url_list
# Out:
# ['https://book.douban.com/tag/哲学?start=0&type=T',
#  'https://book.douban.com/tag/哲学?start=20&type=T',
#  'https://book.douban.com/tag/哲学?start=40&type=T',
#  'https://book.douban.com/tag/哲学?start=60&type=T',
#  'https://book.douban.com/tag/哲学?start=80&type=T']

# %%
# 打开文件
file = open('./data/books_philosophy.csv', 'a+', encoding='utf-8', newline='') 
fieldnames = ['book_name', 'authors', 'publisher', 'pub_time', 'desc', 'score', 'people_num', 'price', 'img'] 
writer = csv.DictWriter(file, fieldnames=fieldnames)    
writer.writeheader() 

# 对所有网址url_list循环步骤2-4
for url in url_list:
    
    html = get_html(url)       # 【步骤2：得到html数据，用函数get_html(url)】
    
    bookinfo_list = extract_bookinfo_list(html)  # 【步骤3：整理成结构化数据，用函数extract_bookinfo_list(html)】
    
    for bookinfo in bookinfo_list:      # 【步骤4：写数据到csv文件】
        writer.writerow(bookinfo)
    
file.close() # 关闭文件

# %%
# 函数：爬虫主函数  main(filename)
# 参数说明：filename为文件名称
# 仅执行命令，不返回任何值
def main(filename):         # 添加：定义函数名
    print('开始采集豆瓣哲学类书籍！')              # 添加：说明“开始采集豆瓣哲学类书籍！”
    
    # 生成所有网址url_list
    url_list = generate_url_list()
    
    # 打开文件
    file = open(filename, 'a+', encoding='utf-8', newline='')     # 修改：将文件名称，设定为函数的参数
    fieldnames = ['book_name', 'authors', 'publisher', 'pub_time', 'desc', 'score', 'people_num', 'price', 'img'] 
    writer = csv.DictWriter(file, fieldnames=fieldnames)    
    writer.writeheader() 

    # 对所有网址url_list循环步骤2-4
    for url in url_list:
        print('正在采集：{url}'.format(url=url))    # 添加：说明“正在采集<url>”
        html = get_html(url)
        bookinfo_list = extract_bookinfo_list(html)
        for bookinfo in bookinfo_list:
            writer.writerow(bookinfo)

    file.close()

    print('采集完毕！')            # 添加：说明“采集完毕！”

# %% [markdown]
# - 修改函数generate_url_list()：
#     1. 原情况：一次性爬取50页网址，且只能爬取哲学类书籍
#     2. 任务：**灵活地设置页数，书籍类型**

# %%
# 新函数：生成网址  generate_url_list(categ, max_page)
# 参数说明：categ为书籍类型，max_page为最大页数
# 返回值：url_list为网址列表
def generate_url_list(categ, max_page):   # 添加：加入参数categ和max_page
    url_list = []
    template = 'https://book.douban.com/tag/{categ}?start={num}&type=T'   # 修改：哲学替换成{categ}
    for p in range(1,max_page+1):        # 修改：51替换成max_page+1
        url = template.format(categ=categ, num=(p-1)*20)       # 添加：加入参数categ
        url_list.append(url)
    return url_list

# %% [markdown]
# **<big>主函数也相应修改</big>**

# %%
# 函数：爬虫主函数  main(categ, max_page, filename)
# 参数说明：categ为书籍类型，max_page为最大页数，filename为文件名称
# 仅执行命令，不返回任何值
def main(categ, max_page, filename):         # 添加：加入参数categ和max_page
    print('开始采集豆瓣{categ}类书籍！'.format(categ = categ))              # 修改：哲学替换成{categ}”
    
    # 生成所有网址url_list
    url_list = generate_url_list(categ, max_page)       # 添加：加入参数categ和max_page
    
    # 打开文件
    file = open(filename, 'a+', encoding='utf-8', newline='')  
    fieldnames = ['book_name', 'authors', 'publisher', 'pub_time', 'desc', 'score', 'people_num', 'price', 'img'] 
    writer = csv.DictWriter(file, fieldnames=fieldnames)    
    writer.writeheader() 

    # 对所有网址url_list循环步骤2-4
    for url in url_list:
        print('正在采集：{url}'.format(url=url))
        html = get_html(url)
        bookinfo_list = extract_bookinfo_list(html)
        for bookinfo in bookinfo_list:
            writer.writerow(bookinfo)

    file.close()

    print('采集完毕！')

# %% [markdown]
# 豆瓣图书类型汇总：https://book.douban.com/tag/?view=type&icn=index-sorttags-hot#文学

# %%
# 调用函数main(categ, max_page, filename)
main(categ='哲学', max_page=10, filename='./data/books_philosophy_2.csv')
# Out:
# 开始采集豆瓣哲学类书籍！
# 正在采集：https://book.douban.com/tag/哲学?start=0&type=T
# 正在采集：https://book.douban.com/tag/哲学?start=20&type=T
# 正在采集：https://book.douban.com/tag/哲学?start=40&type=T
# 正在采集：https://book.douban.com/tag/哲学?start=60&type=T
# 正在采集：https://book.douban.com/tag/哲学?start=80&type=T
# 正在采集：https://book.douban.com/tag/哲学?start=100&type=T
# 正在采集：https://book.douban.com/tag/哲学?start=120&type=T
# 正在采集：https://book.douban.com/tag/哲学?start=140&type=T
# 正在采集：https://book.douban.com/tag/哲学?start=160&type=T
# 正在采集：https://book.douban.com/tag/哲学?start=180&type=T
# 采集完毕！

# %% [markdown]
# main(categ='漫画', max_page=10, filename='output/books_comic_10.csv')

# %%
main(categ='电影', max_page=10, filename='./data/books_movie_10.csv')
# Out:
# 开始采集豆瓣电影类书籍！
# 正在采集：https://book.douban.com/tag/电影?start=0&type=T
# 正在采集：https://book.douban.com/tag/电影?start=20&type=T
# 正在采集：https://book.douban.com/tag/电影?start=40&type=T
# 正在采集：https://book.douban.com/tag/电影?start=60&type=T
# 正在采集：https://book.douban.com/tag/电影?start=80&type=T
# 正在采集：https://book.douban.com/tag/电影?start=100&type=T
# 正在采集：https://book.douban.com/tag/电影?start=120&type=T
# 正在采集：https://book.douban.com/tag/电影?start=140&type=T
# 正在采集：https://book.douban.com/tag/电影?start=160&type=T
# 正在采集：https://book.douban.com/tag/电影?start=180&type=T
# 采集完毕！

# %% [markdown]
# # 参考：
# - [Excel打开监控数据CSV文件乱码如何处理？_云监控服务 CES_常见问题_产品咨询_华为云 ](https://support.huaweicloud.com/ces_faq/ces_faq_0018.html)
